# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
from __future__ import division
import sys
import os
sys.path.append('../')
from modules.basics import *

# %%
RESULTS_PATH = Path('results/')
BLIND = True

# %%
# !ls {RESULTS_PATH}
# Out:
# 0_relu_baseline_daedalus.json
# 0_relu_baseline_helios_cpu.json
# 0_relu_baseline_helios_cuda.json
# 0_relu_baseline_icarus.json
# 0_relu_baseline_mbp.json
# 0_relu_baseline_morpheus.json
# 11_swish_ensemble_embed_aug_swaconst_daedalus.json
# 11_swish_ensemble_embed_aug_swaconst_helios_cpu.json
# 11_swish_ensemble_embed_aug_swaconst_helios_cuda.json
# 11_swish_ensemble_embed_aug_swaconst_icarus.json
# 11_swish_ensemble_embed_aug_swaconst_mbp.json
# 11_swish_ensemble_embed_aug_swaconst_morpheus.json
# 12_swish_ensemble_embed_aug_swacosine1_daedalus.json
# 12_swish_ensemble_embed_aug_swacosine1_helios_cpu.json
# 12_swish_ensemble_embed_aug_swacosine1_helios_cuda.json
# 12_swish_ensemble_embed_aug_swacosine1_icarus.json
# 12_swish_ensemble_embed_aug_swacosine1_mbp.json
# 12_swish_ensemble_embed_aug_swacosine1_morpheus.json
# 13_swish_ensemble_embed_aug_swacyclic_daedalus.json
# 13_swish_ensemble_embed_aug_swacyclic_helios_cpu.json
# 13_swish_ensemble_embed_aug_swacyclic_helios_cuda.json
# 13_swish_ensemble_embed_aug_swacyclic_icarus.json
# 13_swish_ensemble_embed_aug_swacyclic_mbp.json
# 13_swish_ensemble_embed_aug_swacyclic_morpheus.json
# 14_swish_ensemble_embed_aug_sse_daedalus.json
# 14_swish_ensemble_embed_aug_sse_helios_cpu.json
# 14_swish_ensemble_embed_aug_sse_helios_cuda.json
# 14_swish_ensemble_embed_aug_sse_icarus.json
# 14_swish_ensemble_embed_aug_sse_mbp.json
# 14_swish_ensemble_embed_aug_sse_morpheus.json
# 15_swish_ensemble_embed_aug_fge_daedalus.json
# 15_swish_ensemble_embed_aug_fge_helios_cpu.json
# 15_swish_ensemble_embed_aug_fge_helios_cuda.json
# 15_swish_ensemble_embed_aug_fge_icarus.json
# 15_swish_ensemble_embed_aug_fge_mbp.json
# 15_swish_ensemble_embed_aug_fge_morpheus.json
# 18_swish_ensemble_embed_aug_onecycle_daedalus.json
# 18_swish_ensemble_embed_aug_onecycle_helios_cpu.json
# 18_swish_ensemble_embed_aug_onecycle_helios_cuda.json
# 18_swish_ensemble_embed_aug_onecycle_icarus.json
# 18_swish_ensemble_embed_aug_onecycle_mbp.json
# 18_swish_ensemble_embed_aug_onecycle_morpheus.json
# 1_relu_ensemble_daedalus.json
# 1_relu_ensemble_helios_cpu.json
# 1_relu_ensemble_helios_cuda.json
# 1_relu_ensemble_icarus.json
# 1_relu_ensemble_mbp.json
# 1_relu_ensemble_morpheus.json
# 28_swish_ensemble_embed_aug_onecycle_dense_check_daedalus.json
# 28_swish_ensemble_embed_aug_onecycle_dense_check_helios_cpu.json
# 28_swish_ensemble_embed_aug_onecycle_dense_check_helios_cuda.json
# 28_swish_ensemble_embed_aug_onecycle_dense_check_icarus.json
# 28_swish_ensemble_embed_aug_onecycle_dense_check_mbp.json
# 28_swish_ensemble_embed_aug_onecycle_dense_daedalus.json
# 28_swish_ensemble_embed_aug_onecycle_dense_helios_cpu.json
# 28_swish_ensemble_embed_aug_onecycle_dense_helios_cuda.json
# 28_swish_ensemble_embed_aug_onecycle_dense_icarus.json
# 28_swish_ensemble_embed_aug_onecycle_dense_mbp.json
# 28_swish_ensemble_embed_aug_onecycle_dense_morpheus.json
# 29_swish_ensemble_embed_aug_onecycle_dense_split_daedalus.json
# 29_swish_ensemble_embed_aug_onecycle_dense_split_helios_cpu.json
# 29_swish_ensemble_embed_aug_onecycle_dense_split_helios_cuda.json
# 29_swish_ensemble_embed_aug_onecycle_dense_split_icarus.json
# 29_swish_ensemble_embed_aug_onecycle_dense_split_mbp.json
# 29_swish_ensemble_embed_aug_onecycle_dense_split_morpheus.json
# 30_swish_ensemble_embed_aug_onecycle_dense_split_bottleneck_daedalus.json
# 30_swish_ensemble_embed_aug_onecycle_dense_split_bottleneck_helios_cpu.json
# 30_swish_ensemble_embed_aug_onecycle_dense_split_bottleneck_helios_cuda.json
# 30_swish_ensemble_embed_aug_onecycle_dense_split_bottleneck_icarus.json
# 30_swish_ensemble_embed_aug_onecycle_dense_split_bottleneck_mbp.json
# 30_swish_ensemble_embed_aug_onecycle_dense_split_bottleneck_morpheus.json
# 32_swish_ensemble_embed_aug_onecycle_dense_wide-deep_daedalus.json
# 32_swish_ensemble_embed_aug_onecycle_dense_wide-deep_helios_cpu.json
# 32_swish_ensemble_embed_aug_onecycle_dense_wide-deep_helios_cuda.json
# 32_swish_ensemble_embed_aug_onecycle_dense_wide-deep_icarus.json
# 32_swish_ensemble_embed_aug_onecycle_dense_wide-deep_mbp.json
# 32_swish_ensemble_embed_aug_onecycle_dense_wide-deep_morpheus.json
# 33_search_4-100-0.1_daedalus.json
# 33_search_4-100-0.1_helios_cpu.json
# 33_search_4-100-0.1_helios_cuda.json
# 33_search_4-100-0.1_icarus.json
# 33_search_4-100-0.1_mbp.json
# 33_search_4-100-0.1_morpheus.json
# 33_search_4-40-0.45_daedalus.json
# 33_search_4-40-0.45_helios_cpu.json
# 33_search_4-40-0.45_helios_cuda.json
# 33_search_4-40-0.45_icarus.json
# 33_search_4-40-0.45_mbp.json
# 33_search_4-40-0.45_morpheus.json
# 33_search_5-100--0.1_daedalus.json
# 33_search_5-100--0.1_helios_cpu.json
# 33_search_5-100--0.1_helios_cuda.json
# 33_search_5-100--0.1_icarus.json
# 33_search_5-100--0.1_mbp.json
# 33_search_5-100--0.1_morpheus.json
# 33_search_5-33-0.9_daedalus.json
# 33_search_5-33-0.9_helios_cpu.json
# 33_search_5-33-0.9_helios_cuda.json
# 33_search_5-33-0.9_icarus.json
# 33_search_5-33-0.9_mbp.json
# 33_search_5-33-0.9_morpheus.json
# 33_search_8-33-0.2_daedalus.json
# 33_search_8-33-0.2_helios_cpu.json
# 33_search_8-33-0.2_helios_cuda.json
# 33_search_8-33-0.2_icarus.json
# 33_search_8-33-0.2_mbp.json
# 33_search_8-33-0.2_morpheus.json
# 38_baseline+cat_daedalus.json
# 38_baseline+cat_helios_cpu.json
# 38_baseline+cat_helios_cuda.json
# 38_baseline+cat_icarus.json
# 38_baseline+cat_mbp.json
# 38_baseline+cat_morpheus.json
# 39_baseline+swish_daedalus.json
# 39_baseline+swish_helios_cpu.json
# 39_baseline+swish_helios_cuda.json
# 39_baseline+swish_icarus.json
# 39_baseline+swish_mbp.json
# 39_baseline+swish_morpheus.json
# 40_baseline+onecycle_daedalus.json
# 40_baseline+onecycle_helios_cpu.json
# 40_baseline+onecycle_helios_cuda.json
# 40_baseline+onecycle_icarus.json
# 40_baseline+onecycle_mbp.json
# 40_baseline+onecycle_morpheus.json
# 41_baseline+dense_daedalus.json
# 41_baseline+dense_helios_cpu.json
# 41_baseline+dense_helios_cuda.json
# 41_baseline+dense_icarus.json
# 41_baseline+dense_mbp.json
# 41_baseline+dense_morpheus.json
# 42_baseline+aug_daedalus.json
# 42_baseline+aug_helios_cpu.json
# 42_baseline+aug_helios_cuda.json
# 42_baseline+aug_icarus.json
# 42_baseline+aug_icaurs.json
# 42_baseline+aug_mbp.json
# 42_baseline+aug_morpheus.json
# 4_relu_ensemble_embed_daedalus.json
# 4_relu_ensemble_embed_helios_cpu.json
# 4_relu_ensemble_embed_helios_cuda.json
# 4_relu_ensemble_embed_icarus.json
# 4_relu_ensemble_embed_mbp.json
# 4_relu_ensemble_embed_morpheus.json
# 6_relu_ensemble_embed_fix_daedalus.json
# 6_relu_ensemble_embed_fix_helios_cpu.json
# 6_relu_ensemble_embed_fix_helios_cuda.json
# 6_relu_ensemble_embed_fix_icarus.json
# 6_relu_ensemble_embed_fix_mbp.json
# 6_relu_ensemble_embed_fix_morpheus.json
# 7_relu_ensemble_embed_aug_daedalus.json
# 7_relu_ensemble_embed_aug_helios_cpu.json
# 7_relu_ensemble_embed_aug_helios_cuda.json
# 7_relu_ensemble_embed_aug_icarus.json
# 7_relu_ensemble_embed_aug_mbp.json
# 7_relu_ensemble_embed_aug_morpheus.json
# 8_relu_ensemble_embed_aug_cosine_daedalus.json
# 8_relu_ensemble_embed_aug_cosine_helios_cpu.json
# 8_relu_ensemble_embed_aug_cosine_helios_cuda.json
# 8_relu_ensemble_embed_aug_cosine_icarus.json
# 8_relu_ensemble_embed_aug_cosine_mbp.json
# 8_relu_ensemble_embed_aug_cosine_morpheus.json
# 9_swish_ensemble_embed_aug_cosine_daedalus.json
# 9_swish_ensemble_embed_aug_cosine_helios_cpu.json
# 9_swish_ensemble_embed_aug_cosine_helios_cuda.json
# 9_swish_ensemble_embed_aug_cosine_icarus.json
# 9_swish_ensemble_embed_aug_cosine_mbp.json
# 9_swish_ensemble_embed_aug_cosine_morpheus.json

# %% [markdown]
# # ReLU Baseline

# %%
relu_baseline = Result('0_relu_baseline', RESULTS_PATH, is_blind=BLIND)

# %%
relu_baseline
# Out:
# Experiment:	0_relu_baseline
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
relu_baseline.print_results()
# Out:
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	0.14059407399690826±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	0.08680325399836875±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	0.21408750489354134±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0.155±0.002
# 	Nvidia GeForce GTX 1080 Ti GPU	0.04273891499906313±0.0
# val_ams_smooth:	3.38±0.04
# val_ams_max:	3.43±0.04
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	45.22926070699759±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	42.750536903000466±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	67.40384469553828±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	79±4
# 	Nvidia GeForce GTX 1080 Ti GPU	32.43193237400192±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1.0854913719995238±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	0.8953697239994654±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1.689862072467804±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1.25±0.02
# 	Nvidia GeForce GTX 1080 Ti GPU	0.14060635200075922±0.0
# test_public_ams_mean:	3.44±0.02
# test_public_ams:	3.42±0.02

# %%
relu_baseline.print_table_row(relu_baseline)
# Out:
# $3.43\pm0.04$ & $3.38\pm0.04$ & $3.44\pm0.02$ & $0.0\pm0.0$ & $0.0\pm0.0$\\

# %%
relu_baseline.plot()

# %% [markdown]
# # ReLU Ensemble

# %%
relu_ensemble = Result('1_relu_ensemble', RESULTS_PATH, is_blind=BLIND)

# %%
relu_ensemble
# Out:
# Experiment:	1_relu_ensemble
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
relu_ensemble.print_results()
# Out:
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	0.6899246399989352±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	0.5279464089981047±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	0.8965716697275639±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0.65±0.04
# 	Nvidia GeForce GTX 1080 Ti GPU	0.10740485700080171±0.0
# val_ams_smooth:	3.64±0.04
# val_ams_max:	3.7±0.05
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	593.8020349819999±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	423.51287222799874±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	825.025685057044±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	900±200
# 	Nvidia GeForce GTX 1080 Ti GPU	320.3103129170013±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	8.15009481800007±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	7.223349287996825±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	14.14342576265335±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	8.8±0.6
# 	Nvidia GeForce GTX 1080 Ti GPU	0.4649692800012417±0.0
# test_public_ams_mean:	3.664±0.007
# test_public_ams:	3.649±0.01

# %%
relu_ensemble.print_table_row(relu_baseline)
# Out:
# $3.7\pm0.05$ & $3.64\pm0.04$ & $3.664\pm0.007$ & $10.4\pm0.6$ & $5.9\pm0.9$\\

# %%
relu_ensemble.plot()

# %%
relu_ensemble.compare_to(relu_baseline)
# Out:
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	390.72099583237554±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	508.2103892188491±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	318.78748139616994±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	322±4 %
# 	Nvidia GeForce GTX 1080 Ti GPU	151.30459442677972±0.0 %
# val_ams_smooth:	7.8±0.1 %
# val_ams_max:	7.9±0.1 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1212.8714148761899±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	890.6609434846051±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1124.0038958959497±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1100±200 %
# 	Nvidia GeForce GTX 1080 Ti GPU	887.6386927032704±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	650.8207829406539±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	706.744866883743±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	736.957405760275±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	610±10 %
# 	Nvidia GeForce GTX 1080 Ti GPU	230.6886732960194±0.0 %
# test_public_ams_mean:	6.63±0.04 %
# test_public_ams:	6.55±0.04 %

# %% [markdown]
# # ReLU Ensemble Embed

# %%
relu_ensemble_embed = Result('4_relu_ensemble_embed', RESULTS_PATH, is_blind=BLIND)

# %%
relu_ensemble_embed
# Out:
# Experiment:	4_relu_ensemble_embed
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
relu_ensemble_embed.print_results()
# Out:
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	0.7613772799995786±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	0.5104087089966924±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	0.9987899661064148±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0.66±0.05
# 	Nvidia GeForce GTX 1080 Ti GPU	0.11190028799683205±0.0
# val_ams_smooth:	3.7±0.06
# val_ams_max:	3.78±0.05
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	684.8589037730017±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	510.1443688060026±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	929.5266113914549±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1000±100
# 	Nvidia GeForce GTX 1080 Ti GPU	359.7378375809967±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	8.69716411599802±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	7.9880538180004805±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	14.352150447666645±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	10.6±0.3
# 	Nvidia GeForce GTX 1080 Ti GPU	0.4606651710018923±0.0
# test_public_ams_mean:	3.71±0.02
# test_public_ams:	3.68±0.02

# %%
relu_ensemble_embed.print_table_row(relu_ensemble)
# Out:
# $3.78\pm0.05$ & $3.7\pm0.06$ & $3.71\pm0.02$ & $0.13\pm0.03$ & $0.08\pm0.04$\\

# %%
relu_ensemble_embed.plot()

# %%
relu_ensemble_embed.compare_to(relu_ensemble)
# Out:
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	10.356586191899702±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-3.321871254829439±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	11.40101788069117±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0.72±0.08 %
# 	Nvidia GeForce GTX 1080 Ti GPU	4.185500657569686±0.0 %
# val_ams_smooth:	1.58±0.07 %
# val_ams_max:	1.96±0.07 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	15.334549803919414±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	20.455457734320216±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	12.666384601975814±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±200 %
# 	Nvidia GeForce GTX 1080 Ti GPU	12.309164917275666±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	6.712428630765232±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	10.586564480197282±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1.4757717721009682±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	20±2 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-0.9256759929038572±0.0 %
# test_public_ams_mean:	1.32±0.02 %
# test_public_ams:	0.95±0.02 %

# %% [markdown]
# # ReLU Ensemble Embed data-fixing

# %%
relu_ensemble_embed_fix = Result('6_relu_ensemble_embed_fix', RESULTS_PATH, is_blind=BLIND)

# %%
relu_ensemble_embed_fix
# Out:
# Experiment:	6_relu_ensemble_embed_fix
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
relu_ensemble_embed_fix.print_results()
# Out:
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	0.7604494400002295±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	0.5526868300003116±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	0.9852008745074272±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0.7±0.04
# 	Nvidia GeForce GTX 1080 Ti GPU	0.10821266399943852±0.0
# val_ams_smooth:	3.83±0.05
# val_ams_max:	3.9±0.04
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	657.1545228050018±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	555.9174366219995±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	862.9456472806633±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1100±200
# 	Nvidia GeForce GTX 1080 Ti GPU	386.81688965800095±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	8.721801882998989±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	8.654346570998314±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	14.884700991213322±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	10.7±0.3
# 	Nvidia GeForce GTX 1080 Ti GPU	0.46180686600018817±0.0
# test_public_ams_mean:	3.76±0.01
# test_public_ams:	3.73±0.01

# %%
relu_ensemble_embed_fix.print_table_row(relu_ensemble_embed)
# Out:
# $3.9\pm0.04$ & $3.83\pm0.05$ & $3.76\pm0.01$ & $0.03\pm0.04$ & $0.03\pm0.02$\\

# %%
relu_ensemble_embed_fix.plot()

# %%
relu_ensemble_embed_fix.compare_to(relu_ensemble_embed)
# Out:
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-0.12186336836181963±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	8.28318958089979±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-1.3605554781414122±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	5.6±0.4 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-3.2954553231336887±0.0 %
# val_ams_smooth:	3.53±0.09 %
# val_ams_max:	3.24±0.08 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-4.045268421768608±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	8.97257141603448±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-7.162889506855894±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±200 %
# 	Nvidia GeForce GTX 1080 Ti GPU	7.527440610388185±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	0.2832850647908077±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	8.341114972164966±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	3.7105975546212173±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1.3±0.4 %
# 	Nvidia GeForce GTX 1080 Ti GPU	0.24783618779184233±0.0 %
# test_public_ams_mean:	1.16±0.02 %
# test_public_ams:	1.28±0.03 %

# %% [markdown]
# # ReLU Ensemble Embed Aug

# %%
relu_ensemble_embed_aug = Result('7_relu_ensemble_embed_aug', RESULTS_PATH, is_blind=BLIND)

# %%
relu_ensemble_embed_aug
# Out:
# Experiment:	7_relu_ensemble_embed_aug
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
relu_ensemble_embed_aug.print_results()
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	0.7701200960000278±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	0.5548700030012697±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	0.9829583577811718±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0.633±0.002
# 	Nvidia GeForce GTX 1080 Ti GPU	0.10381101699931605±0.0
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	9.568701434000104±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	6.986393130999204±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	12.648118067532778±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	10.1±0.3
# 	Nvidia GeForce GTX 1080 Ti GPU	3.9004398100005346±0.0
# val_ams_smooth_no_tta:	3.87±0.05
# val_ams_smooth:	3.89±0.05
# val_ams_max_no_tta:	3.94±0.04
# val_ams_max:	3.96±0.04
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1420.586964852002±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1105.1190962319997±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1917.0427521020174±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	2100±300
# 	Nvidia GeForce GTX 1080 Ti GPU	856.456601979±0.0
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	8.769647453998914±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	8.125343764999343±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	14.574983302503824±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	10.4±0.6
# 	Nvidia GeForce GTX 1080 Ti GPU	0.4685391380007786±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	96.96949299300104±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	76.8027273100015±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	127.36496529355645±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	90±6
# 	Nvidia GeForce GTX 1080 Ti GPU	15.702224503000252±0.0
# test_public_ams_no_tta:	3.762±0.006
# test_public_ams_mean_no_tta:	3.774±0.007
# test_public_ams_mean:	3.79±0.01
# test_public_ams:	3.772±0.009

# %%
relu_ensemble_embed_aug.print_table_row(relu_ensemble_embed_fix)
# Out:
# $3.96\pm0.04$ & $3.89\pm0.05$ & $3.79\pm0.01$ & $1.11\pm0.05$ & $13\pm5$\\

# %%
relu_ensemble_embed_aug.print_table_row(relu_ensemble)
# Out:
# $3.96\pm0.04$ & $3.89\pm0.05$ & $3.79\pm0.01$ & $1.45\pm0.08$ & $14\pm5$\\

# %%
relu_ensemble_embed_aug.plot()

# %%
relu_ensemble_embed_aug.compare_to(relu_ensemble_embed_fix)
# Out:
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1158.2955461177296±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1164.078091203162±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1183.8110881556497±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1360±80 %
# 	Nvidia GeForce GTX 1080 Ti GPU	3504.420837491601±0.0 %
# val_ams_smooth:	1.62±0.07 %
# val_ams_max:	1.49±0.06 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	116.17243974649391±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	98.79194704652414±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	122.15104255326536±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	100±400 %
# 	Nvidia GeForce GTX 1080 Ti GPU	121.4113770306733±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1011.8057288370567±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	787.4468647624542±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	755.6770160767222±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	740±20 %
# 	Nvidia GeForce GTX 1080 Ti GPU	3300.171296499055±0.0 %
# test_public_ams_mean:	0.82±0.02 %
# test_public_ams:	1.11±0.02 %

# %% [markdown]
# # ReLU Ensemble Embed Aug Cosine

# %%
relu_ensemble_embed_aug_cosine = Result('8_relu_ensemble_embed_aug_cosine', RESULTS_PATH, is_blind=BLIND)
relu_ensemble_embed_aug_cosine
# Out:
# Experiment:	8_relu_ensemble_embed_aug_cosine
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
relu_ensemble_embed_aug_cosine.print_results()
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	0.7822962870013725±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	0.5358222890008619±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	0.9519818052649498±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0.69±0.05
# 	Nvidia GeForce GTX 1080 Ti GPU	0.10334181300095224±0.0
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	10.530989639999461±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	7.052974219001044±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	12.615795504301786±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	10.2±0.6
# 	Nvidia GeForce GTX 1080 Ti GPU	3.9427943880000385±0.0
# val_ams_smooth_no_tta:	3.89±0.05
# val_ams_smooth:	3.9±0.04
# val_ams_max_no_tta:	3.95±0.05
# val_ams_max:	3.94±0.06
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1872.3703625300004±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1336.9412542690006±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	2496.386730764061±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	2700±400
# 	Nvidia GeForce GTX 1080 Ti GPU	1071.2552189010003±0.0
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	8.888548886003264±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	8.150053145998754±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	14.967655908316374±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	10.5±0.1
# 	Nvidia GeForce GTX 1080 Ti GPU	0.4764783670016186±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	91.79057268899851±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	72.32156363399918±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	124.75855591148138±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	89±7
# 	Nvidia GeForce GTX 1080 Ti GPU	15.776565760001176±0.0
# test_public_ams_no_tta:	3.77±0.01
# test_public_ams_mean_no_tta:	3.79±0.01
# test_public_ams_mean:	3.8±0.02
# test_public_ams:	3.79±0.02

# %%
relu_ensemble_embed_aug_cosine.print_table_row(relu_ensemble)
# Out:
# $3.94\pm0.06$ & $3.9\pm0.04$ & $3.8\pm0.02$ & $2.12\pm0.07$ & $14\pm5$\\

# %%
relu_ensemble_embed_aug_cosine.plot()

# %%
relu_ensemble_embed_aug_cosine.compare_to(relu_ensemble_embed_aug)
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1.5810769079507652±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-3.4328246070934454±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-3.151359594331672±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	8.88±0.06 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-0.4519790017729053±0.0 %
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	10.056622757400445±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	0.9530108992351722±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-0.2555523522029899±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0.7±0.7 %
# 	Nvidia GeForce GTX 1080 Ti GPU	1.0858923624691958±0.0 %
# val_ams_smooth_no_tta:	0.6±0.07 %
# val_ams_smooth:	0.34±0.07 %
# val_ams_max_no_tta:	0.28±0.06 %
# val_ams_max:	-0.36±0.07 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	31.80258645587851±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	20.977119916524728±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	30.220712502462412±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±500 %
# 	Nvidia GeForce GTX 1080 Ti GPU	25.079918401664337±0.0 %
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1.355829098353678±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	0.30410259201400347±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	2.694154755876068±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0.3±0.6 %
# 	Nvidia GeForce GTX 1080 Ti GPU	1.694464422911623±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-5.340772797869873±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-5.834641337559341±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-2.0464099967111857±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-1±10 %
# 	Nvidia GeForce GTX 1080 Ti GPU	0.47344410969744805±0.0 %
# test_public_ams_no_tta:	0.26±0.01 %
# test_public_ams_mean_no_tta:	0.31±0.02 %
# test_public_ams_mean:	0.42±0.02 %
# test_public_ams:	0.42±0.02 %

# %% [markdown]
# # Swish Ensemble Embed Aug Cosine

# %%
swish_ensemble_embed_aug_cosine = Result('9_swish_ensemble_embed_aug_cosine', RESULTS_PATH, is_blind=BLIND)

# %%
swish_ensemble_embed_aug_cosine
# Out:
# Experiment:	9_swish_ensemble_embed_aug_cosine
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
swish_ensemble_embed_aug_cosine.print_results()
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1.180895031997352±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	0.8489471129996673±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1.322226032614708±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0.83±0.04
# 	Nvidia GeForce GTX 1080 Ti GPU	0.11632665400020414±0.0
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	12.64778947800005±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	8.847477996000634±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	14.537162810564041±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	11.4±0.4
# 	Nvidia GeForce GTX 1080 Ti GPU	3.982635387999835±0.0
# val_ams_smooth_no_tta:	3.86±0.05
# val_ams_smooth:	3.86±0.05
# val_ams_max_no_tta:	3.95±0.07
# val_ams_max:	3.96±0.06
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	2059.6913701660014±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1410.502052979±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	2677.11003062129±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	2900±300
# 	Nvidia GeForce GTX 1080 Ti GPU	1106.806600719±0.0
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	13.616638962997968±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	12.387806147999981±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	20.78089588880539±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	15.0±0.5
# 	Nvidia GeForce GTX 1080 Ti GPU	0.6015742340000543±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	124.19971454199913±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	108.27907101399978±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	174.5848509632051±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	126±7
# 	Nvidia GeForce GTX 1080 Ti GPU	16.509969547999845±0.0
# test_public_ams_no_tta:	3.78±0.01
# test_public_ams_mean_no_tta:	3.81±0.01
# test_public_ams_mean:	3.81±0.02
# test_public_ams:	3.79±0.01

# %%
swish_ensemble_embed_aug_cosine.print_table_row(relu_ensemble)
# Out:
# $3.96\pm0.06$ & $3.86\pm0.05$ & $3.81\pm0.02$ & $2.32\pm0.07$ & $17\pm4$\\

# %%
swish_ensemble_embed_aug_cosine.plot()

# %%
swish_ensemble_embed_aug_cosine.compare_to(relu_ensemble_embed_aug_cosine)
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	50.95240149021441±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	58.43818564970179±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	38.891943659229284±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	20±1 %
# 	Nvidia GeForce GTX 1080 Ti GPU	12.564944064927769±0.0 %
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	20.10067344440666±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	25.443220424159684±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	15.229854555006849±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	12±1 %
# 	Nvidia GeForce GTX 1080 Ti GPU	1.0104762277498767±0.0 %
# val_ams_smooth_no_tta:	-0.73±0.07 %
# val_ams_smooth:	-1.01±0.07 %
# val_ams_max_no_tta:	-0.04±0.08 %
# val_ams_max:	0.45±0.08 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	10.004484763521225±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	5.502171353835597±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	7.2393951477988985±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±500 %
# 	Nvidia GeForce GTX 1080 Ti GPU	3.3186659155296234±0.0 %
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	53.193048017545294±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	51.99663028064719±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	38.83867999169493±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	43.6±0.8 %
# 	Nvidia GeForce GTX 1080 Ti GPU	26.254259513530172±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	35.307701982433535±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	49.71892969844001±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	39.938178738680215±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	40±10 %
# 	Nvidia GeForce GTX 1080 Ti GPU	4.648690970870795±0.0 %
# test_public_ams_no_tta:	0.3±0.02 %
# test_public_ams_mean_no_tta:	0.63±0.02 %
# test_public_ams_mean:	0.32±0.02 %
# test_public_ams:	0.03±0.02 %

# %% [markdown]
# # Swish Ensemble Aug SWA constant LR

# %%
swish_ensemble_embed_aug_swaconst = Result('11_swish_ensemble_embed_aug_swaconst', RESULTS_PATH, is_blind=BLIND)

# %%
swish_ensemble_embed_aug_swaconst
# Out:
# Experiment:	11_swish_ensemble_embed_aug_swaconst
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
swish_ensemble_embed_aug_swaconst.print_results()
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1.2981807420001132±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	0.6652977190005913±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1.2526923902332783±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0.83±0.05
# 	Nvidia GeForce GTX 1080 Ti GPU	0.13039200699950015±0.0
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	12.930596418002096±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	8.614669501999742±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	14.550765987485647±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	11.3±0.4
# 	Nvidia GeForce GTX 1080 Ti GPU	4.029719817000114±0.0
# val_ams_smooth_no_tta:	3.86±0.06
# val_ams_smooth:	3.88±0.05
# val_ams_max_no_tta:	3.94±0.06
# val_ams_max:	3.96±0.06
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1893.788950954±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1339.652004303999±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	2427.996422443539±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	2600±400
# 	Nvidia GeForce GTX 1080 Ti GPU	977.60500013±0.0
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	13.58735955800148±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	12.5380606359995±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	20.243837229907513±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	14.6±0.4
# 	Nvidia GeForce GTX 1080 Ti GPU	0.5995923609998499±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	122.97330230599982±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	110.76835791099984±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	172.54157750308514±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	123±8
# 	Nvidia GeForce GTX 1080 Ti GPU	16.590213948000383±0.0
# test_public_ams_no_tta:	3.78±0.01
# test_public_ams_mean_no_tta:	3.8±0.02
# test_public_ams_mean:	3.81±0.02
# test_public_ams:	3.8±0.02

# %%
swish_ensemble_embed_aug_swaconst.print_table_row(swish_ensemble_embed_aug_cosine)
# Out:
# $3.96\pm0.06$ & $3.88\pm0.05$ & $3.81\pm0.02$ & $-0.09\pm0.01$ & $-0.004\pm0.008$\\

# %%
swish_ensemble_embed_aug_swaconst.print_table_row(relu_ensemble)
# Out:
# $3.96\pm0.06$ & $3.88\pm0.05$ & $3.81\pm0.02$ & $2.03\pm0.07$ & $17\pm4$\\

# %%
swish_ensemble_embed_aug_swaconst.plot()

# %%
swish_ensemble_embed_aug_swaconst.compare_to(swish_ensemble_embed_aug_cosine)
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	9.931933560969062±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-21.63260716561833±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-5.258831747846212±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-0.13±0.06 %
# 	Nvidia GeForce GTX 1080 Ti GPU	12.091255542578683±0.0 %
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	2.2360187168988683±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-2.6313543148242875±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	0.0935751845038204±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-1.1±0.6 %
# 	Nvidia GeForce GTX 1080 Ti GPU	1.1822430228524023±0.0 %
# val_ams_smooth_no_tta:	-0.24±0.08 %
# val_ams_smooth:	0.34±0.08 %
# val_ams_max_no_tta:	-0.46±0.09 %
# val_ams_max:	-0.05±0.08 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-8.054722256695694±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-5.0230376145404785±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-9.305318247227152±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±500 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-11.673367371053669±0.0 %
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-0.21502666756496286±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1.2129224997904664±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-2.5843864565395793±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-2.6±0.6 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-0.32944778685520976±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-0.9874517349108592±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	2.2989547967937476±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-1.1703612592083352±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±10 %
# 	Nvidia GeForce GTX 1080 Ti GPU	0.48603602670036106±0.0 %
# test_public_ams_no_tta:	-0.07±0.02 %
# test_public_ams_mean_no_tta:	-0.38±0.02 %
# test_public_ams_mean:	0.01±0.03 %
# test_public_ams:	0.22±0.02 %

# %% [markdown]
# # Swish Ensemble Aug SWA cosine1 cycled LR

# %%
swish_ensemble_embed_aug_swacosine1 = Result('12_swish_ensemble_embed_aug_swacosine1', RESULTS_PATH, is_blind=BLIND)

# %%
swish_ensemble_embed_aug_swacosine1
# Out:
# Experiment:	12_swish_ensemble_embed_aug_swacosine1
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
swish_ensemble_embed_aug_swacosine1.print_results()
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1.1676869560033083±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	0.7325581170007354±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1.1954853869974613±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0.83±0.06
# 	Nvidia GeForce GTX 1080 Ti GPU	0.10830168800021056±0.0
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	12.852897690001555±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	8.818287483001768±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	14.645458981394768±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	11.5±0.6
# 	Nvidia GeForce GTX 1080 Ti GPU	3.96144457599803±0.0
# val_ams_smooth_no_tta:	3.85±0.06
# val_ams_smooth:	3.89±0.05
# val_ams_max_no_tta:	3.99±0.04
# val_ams_max:	3.95±0.05
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	2420.379591060999±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1852.9611068070008±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	3554.8340887874365±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	3500±600
# 	Nvidia GeForce GTX 1080 Ti GPU	1208.1863263710002±0.0
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	13.809820383001352±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	12.666182169999956±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	20.4892014041543±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	15±1
# 	Nvidia GeForce GTX 1080 Ti GPU	0.5546061519999057±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	122.71761480900022±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	108.37381157400159±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	180.2540340386331±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	125±8
# 	Nvidia GeForce GTX 1080 Ti GPU	16.36685232599848±0.0
# test_public_ams_no_tta:	3.8±0.02
# test_public_ams_mean_no_tta:	3.82±0.02
# test_public_ams_mean:	3.81±0.02
# test_public_ams:	3.79±0.01

# %%
swish_ensemble_embed_aug_swacosine1.print_table_row(swish_ensemble_embed_aug_cosine)
# Out:
# $3.95\pm0.05$ & $3.89\pm0.05$ & $3.81\pm0.02$ & $0.22\pm0.04$ & $0.001\pm0.008$\\

# %%
swish_ensemble_embed_aug_swacosine1.plot()

# %%
swish_ensemble_embed_aug_swacosine1.compare_to(swish_ensemble_embed_aug_swaconst)
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-10.052050671754115±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	10.109819420571961±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-4.566723936525532±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-0.02±0.08 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-16.9414671248785±0.0 %
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-0.6008905195770287±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	2.363619184169044±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	0.6507766944404236±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1.4±0.7 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-1.69429250922241±0.0 %
# val_ams_smooth_no_tta:	-0.04±0.08 %
# val_ams_smooth:	0.43±0.07 %
# val_ams_max_no_tta:	1.28±0.07 %
# val_ams_max:	-0.27±0.08 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	27.806194552023744±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	38.316600195711686±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	46.410186437171376±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±700 %
# 	Nvidia GeForce GTX 1080 Ti GPU	23.5863489047558±0.0 %
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1.6372631050958366±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1.021860858070758±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1.2120438010847858±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	5±1 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-7.502798889053136±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-0.20792114402470907±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-2.1617602555074584±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	4.4699119175551±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±10 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-1.346345639073719±0.0 %
# test_public_ams_no_tta:	0.59±0.02 %
# test_public_ams_mean_no_tta:	0.75±0.02 %
# test_public_ams_mean:	-0.07±0.03 %
# test_public_ams:	-0.21±0.02 %

# %% [markdown]
# # Swish Ensemble Aug SWA linear cycled LR

# %%
swish_ensemble_embed_aug_swacyclic = Result('13_swish_ensemble_embed_aug_swacyclic', RESULTS_PATH, is_blind=BLIND)

# %%
swish_ensemble_embed_aug_swacyclic
# Out:
# Experiment:	13_swish_ensemble_embed_aug_swacyclic
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
swish_ensemble_embed_aug_swacyclic.print_results()
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1.1044079720013542±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	0.7746674600020924±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1.2455177530646324±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0.88±0.04
# 	Nvidia GeForce GTX 1080 Ti GPU	0.12509648500054027±0.0
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	12.692809986998327±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	8.704492436001601±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	14.438893765211105±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	11.5±0.6
# 	Nvidia GeForce GTX 1080 Ti GPU	4.028930513002706±0.0
# val_ams_smooth_no_tta:	3.86±0.05
# val_ams_smooth:	3.87±0.04
# val_ams_max_no_tta:	3.96±0.06
# val_ams_max:	3.97±0.06
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	2622.207125656998±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1642.0912686990014±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	3591.4574477672577±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	3700±200
# 	Nvidia GeForce GTX 1080 Ti GPU	1326.9555602670007±0.0
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	13.400210111998604±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	12.711532397002884±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	20.6189188323915±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	15±2
# 	Nvidia GeForce GTX 1080 Ti GPU	0.5939851590010221±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	122.37544896600593±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	107.95448505999957±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	179.16342117264867±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	120±10
# 	Nvidia GeForce GTX 1080 Ti GPU	16.580025380000734±0.0
# test_public_ams_no_tta:	3.79±0.02
# test_public_ams_mean_no_tta:	3.81±0.02
# test_public_ams_mean:	3.81±0.02
# test_public_ams:	3.79±0.01

# %%
swish_ensemble_embed_aug_swacyclic.print_table_row(swish_ensemble_embed_aug_cosine)
# Out:
# $3.97\pm0.06$ & $3.87\pm0.04$ & $3.81\pm0.02$ & $0.25\pm0.03$ & $-0.003\pm0.009$\\

# %%
swish_ensemble_embed_aug_swacyclic.plot()

# %%
swish_ensemble_embed_aug_swacyclic.compare_to(swish_ensemble_embed_aug_swaconst)
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-14.926486253386598±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	16.43921779347088±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-0.5727373475390704±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	5.8±0.3 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-4.061232065382799±0.0 %
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-1.8389440310171687±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1.0426741731764406±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-0.768840776978733±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1.7±0.7 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-0.01958706890930774±0.0 %
# val_ams_smooth_no_tta:	0.19±0.07 %
# val_ams_smooth:	-0.19±0.07 %
# val_ams_max_no_tta:	0.68±0.08 %
# val_ams_max:	0.2±0.08 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	38.46353493276301±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	22.575957295128383±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	47.91856423547816±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±400 %
# 	Nvidia GeForce GTX 1080 Ti GPU	35.735349153343606±0.0 %
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-1.3773790647401125±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1.3835613500329456±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1.8528187034118997±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1±2 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-0.9351690187442545±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-0.4861651503073611±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-2.5403218970359385±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	3.837824926252995±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±10 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-0.06141311999702415±0.0 %
# test_public_ams_no_tta:	0.26±0.02 %
# test_public_ams_mean_no_tta:	0.47±0.03 %
# test_public_ams_mean:	-0.08±0.03 %
# test_public_ams:	-0.23±0.02 %

# %% [markdown]
# # Swish Ensemble Aug SSE

# %%
swish_ensemble_embed_aug_sse = Result('14_swish_ensemble_embed_aug_sse', RESULTS_PATH, is_blind=BLIND)

# %%
swish_ensemble_embed_aug_sse
# Out:
# Experiment:	14_swish_ensemble_embed_aug_sse
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
swish_ensemble_embed_aug_sse.print_results()
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	3.078499750001356±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	2.171913031001168±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	4.063446883112192±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	2.22±0.02
# 	Nvidia GeForce GTX 1080 Ti GPU	0.3125324139982695±0.0
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	27.911015124998812±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	19.797055982002348±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	34.47793332114816±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	20±1
# 	Nvidia GeForce GTX 1080 Ti GPU	5.497545831000025±0.0
# val_ams_smooth_no_tta:	3.85±0.05
# val_ams_smooth:	3.85±0.05
# val_ams_max_no_tta:	3.94±0.05
# val_ams_max:	3.95±0.05
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	2173.1438757009964±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1658.0460404290025±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	3228.726092852652±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	3200±400
# 	Nvidia GeForce GTX 1080 Ti GPU	1340.3646095469994±0.0
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	38.684716076997574±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	37.59954557200035±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	71.62845735996962±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	38±4
# 	Nvidia GeForce GTX 1080 Ti GPU	1.7288183470009244±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	312.6553731880049±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	317.5911778000009±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	535.7932204380631±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	300±20
# 	Nvidia GeForce GTX 1080 Ti GPU	25.448264331000246±0.0
# test_public_ams_no_tta:	3.78±0.01
# test_public_ams_mean_no_tta:	3.81±0.02
# test_public_ams_mean:	3.81±0.02
# test_public_ams:	3.78±0.02

# %%
swish_ensemble_embed_aug_sse.print_table_row(swish_ensemble_embed_aug_cosine)
# Out:
# $3.95\pm0.05$ & $3.85\pm0.05$ & $3.81\pm0.02$ & $0.15\pm0.03$ & $1.5\pm0.3$\\

# %%
swish_ensemble_embed_aug_sse.plot()

# %%
swish_ensemble_embed_aug_sse.compare_to(swish_ensemble_embed_aug_swaconst)
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	137.13953307135776±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	226.4573091072386±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	224.37707092285368±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	168±10 %
# 	Nvidia GeForce GTX 1080 Ti GPU	139.68678846968552±0.0 %
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	115.85249607002534±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	129.80633183207797±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	136.94926680011775±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	84±3 %
# 	Nvidia GeForce GTX 1080 Ti GPU	36.42501416122325±0.0 %
# val_ams_smooth_no_tta:	-0.16±0.08 %
# val_ams_smooth:	-0.75±0.08 %
# val_ams_max_no_tta:	0.07±0.07 %
# val_ams_max:	-0.32±0.08 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	14.751111764923477±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	23.766921193121444±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	32.979030076298784±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±600 %
# 	Nvidia GeForce GTX 1080 Ti GPU	37.10697156507591±0.0 %
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	184.71106480888315±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	199.88326475343302±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	253.82845923177214±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	163±6 %
# 	Nvidia GeForce GTX 1080 Ti GPU	188.33228363984398±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	154.24654565265791±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	186.71651705370502±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	210.52991875450013±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	140±30 %
# 	Nvidia GeForce GTX 1080 Ti GPU	53.393225733942536±0.0 %
# test_public_ams_no_tta:	-0.02±0.02 %
# test_public_ams_mean_no_tta:	0.36±0.02 %
# test_public_ams_mean:	-0.08±0.03 %
# test_public_ams:	-0.36±0.03 %

# %% [markdown]
# # Swish Ensemble Aug FGE

# %%
swish_ensemble_embed_aug_fge = Result('15_swish_ensemble_embed_aug_fge', RESULTS_PATH, is_blind=BLIND)

# %%
swish_ensemble_embed_aug_fge
# Out:
# Experiment:	15_swish_ensemble_embed_aug_fge
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
swish_ensemble_embed_aug_fge.print_results()
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	9.14037665000069±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	5.731774509999923±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	9.839756060391665±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	6.1±0.01
# 	Nvidia GeForce GTX 1080 Ti GPU	0.6711971729998822±0.0
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	75.38497266200284±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	49.65925015599987±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	78.1474175453186±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	50±1
# 	Nvidia GeForce GTX 1080 Ti GPU	8.249176231000092±0.0
# val_ams_smooth_no_tta:	3.85±0.05
# val_ams_smooth:	3.86±0.05
# val_ams_max_no_tta:	3.94±0.06
# val_ams_max:	3.95±0.06
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1695.9010073329991±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1307.829086329±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	2205.9688397161663±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	2700±400
# 	Nvidia GeForce GTX 1080 Ti GPU	933.6281883590001±0.0
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	114.25910611199652±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	116.14579982099986±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	182.5331833064556±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	120±10
# 	Nvidia GeForce GTX 1080 Ti GPU	4.0796203899999455±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	925.2063428580004±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	871.0913150279998±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1355.4639082811773±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	950±40
# 	Nvidia GeForce GTX 1080 Ti GPU	44.13149774700014±0.0
# test_public_ams_no_tta:	3.77±0.01
# test_public_ams_mean_no_tta:	3.79±0.01
# test_public_ams_mean:	3.8±0.02
# test_public_ams:	3.78±0.02

# %%
swish_ensemble_embed_aug_fge.print_table_row(swish_ensemble_embed_aug_cosine)
# Out:
# $3.95\pm0.06$ & $3.86\pm0.05$ & $3.8\pm0.02$ & $-0.13\pm0.03$ & $6\pm1$\\

# %%
swish_ensemble_embed_aug_fge.plot()

# %%
swish_ensemble_embed_aug_fge.compare_to(swish_ensemble_embed_aug_swaconst)
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	604.0912219910201±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	761.535271548831±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	685.4886113389169±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	640±40 %
# 	Nvidia GeForce GTX 1080 Ti GPU	414.7533107627181±0.0 %
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	482.9968721090945±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	476.4498585171765±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	437.06737921927345±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	340±10 %
# 	Nvidia GeForce GTX 1080 Ti GPU	104.7084314944038±0.0 %
# val_ams_smooth_no_tta:	-0.04±0.07 %
# val_ams_smooth:	-0.38±0.07 %
# val_ams_max_no_tta:	0.04±0.08 %
# val_ams_max:	-0.35±0.08 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-10.449313452869943±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-2.375461528274459±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-9.144477342512877±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±500 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-4.498423367837927±0.0 %
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	740.9220763184286±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	826.345813702001±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	801.6728460787448±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	720±20 %
# 	Nvidia GeForce GTX 1080 Ti GPU	580.3989936090875±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	652.3635825894706±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	686.4080784946765±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	685.5868295031329±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	670±60 %
# 	Nvidia GeForce GTX 1080 Ti GPU	166.00921413867184±0.0 %
# test_public_ams_no_tta:	-0.25±0.02 %
# test_public_ams_mean_no_tta:	-0.05±0.02 %
# test_public_ams_mean:	-0.28±0.03 %
# test_public_ams:	-0.47±0.03 %

# %% [markdown]
# # Swish Ensemble Aug onecycle

# %%
swish_ensemble_embed_aug_onecycle = Result('18_swish_ensemble_embed_aug_onecycle', RESULTS_PATH, is_blind=BLIND)

# %%
swish_ensemble_embed_aug_onecycle
# Out:
# Experiment:	18_swish_ensemble_embed_aug_onecycle
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
swish_ensemble_embed_aug_onecycle.print_results()
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1.113117647999843±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	0.7194730829996843±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1.2346289120614529±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0.845±0.001
# 	Nvidia GeForce GTX 1080 Ti GPU	0.12196836999964944±0.0
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	13.182792342999846±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	8.706540749999931±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	14.90944303944707±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	11.3±0.5
# 	Nvidia GeForce GTX 1080 Ti GPU	4.1197253340001225±0.0
# val_ams_smooth_no_tta:	3.85±0.06
# val_ams_smooth:	3.85±0.04
# val_ams_max_no_tta:	3.96±0.04
# val_ams_max:	4.04±0.06
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1022.304935274±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	720.4532002700003±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1349.290034815669±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1400±200
# 	Nvidia GeForce GTX 1080 Ti GPU	547.5865326750002±0.0
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	13.763125534999972±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	11.420839560000331±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	20.596953347325325±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	13.9±0.2
# 	Nvidia GeForce GTX 1080 Ti GPU	0.5605142409999644±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	124.83052767100003±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	103.87103197000033±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	172.0441597290337±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	120±8
# 	Nvidia GeForce GTX 1080 Ti GPU	16.546964823000053±0.0
# test_public_ams_no_tta:	3.78±0.02
# test_public_ams_mean_no_tta:	3.81±0.02
# test_public_ams_mean:	3.81±0.02
# test_public_ams:	3.79±0.02

# %%
swish_ensemble_embed_aug_onecycle.print_table_row(swish_ensemble_embed_aug_swaconst)
# Out:
# $4.04\pm0.06$ & $3.85\pm0.04$ & $3.81\pm0.02$ & $-0.452\pm0.004$ & $-0.02\pm0.01$\\

# %%
swish_ensemble_embed_aug_onecycle.print_table_row(relu_ensemble)
# Out:
# $4.04\pm0.06$ & $3.85\pm0.04$ & $3.81\pm0.02$ & $0.66\pm0.04$ & $17\pm4$\\

# %%
swish_ensemble_embed_aug_onecycle.plot()

# %%
swish_ensemble_embed_aug_onecycle.compare_to(swish_ensemble_embed_aug_swaconst)
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-14.25557227995407±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	8.14302566382988±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-1.441972371881464±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1.9±0.1 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-6.460240312033087±0.0 %
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1.950381226396026±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1.0664512199668525±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	2.4650046071107274±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0.2±0.7 %
# 	Nvidia GeForce GTX 1080 Ti GPU	2.2335428041499035±0.0 %
# val_ams_smooth_no_tta:	-0.21±0.08 %
# val_ams_smooth:	-0.72±0.07 %
# val_ams_max_no_tta:	0.58±0.07 %
# val_ams_max:	2.01±0.09 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-46.01801141785035±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-46.220869453011154±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-44.42784090028676±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±400 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-43.9869341296144±0.0 %
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1.2935992180687093±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-8.910637046939968±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1.7443141505609983±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-5.2±0.5 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-6.517447943252785±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1.5102671312987832±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-6.226801652635649±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-0.28828864396034265±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±10 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-0.2606905802172752±0.0 %
# test_public_ams_no_tta:	0.0±0.02 %
# test_public_ams_mean_no_tta:	0.39±0.02 %
# test_public_ams_mean:	0.03±0.03 %
# test_public_ams:	-0.27±0.03 %

# %% [markdown]
# # 28 dense

# %%
swish_ensemble_embed_aug_onecycle_dense = Result('28_swish_ensemble_embed_aug_onecycle_dense', RESULTS_PATH, is_blind=BLIND)

# %%
swish_ensemble_embed_aug_onecycle_dense
# Out:
# Experiment:	28_swish_ensemble_embed_aug_onecycle_dense
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
swish_ensemble_embed_aug_onecycle_dense.print_results()
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1.667773704000865±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	0.8577028159998008±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1.4468396278098226±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1.0±0.08
# 	Nvidia GeForce GTX 1080 Ti GPU	0.1380136739999216±0.0
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	16.23148224400029±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	10.221903548999762±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	16.10929448250681±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	12.4±0.5
# 	Nvidia GeForce GTX 1080 Ti GPU	4.430980633999752±0.0
# val_ams_smooth_no_tta:	3.86±0.05
# val_ams_smooth:	3.89±0.05
# val_ams_max_no_tta:	3.94±0.06
# val_ams_max:	3.95±0.04
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1076.6543260019998±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	773.8605283829984±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1374.4718355601653±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1500±200
# 	Nvidia GeForce GTX 1080 Ti GPU	668.9149720979995±0.0
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	18.62745519500004±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	13.60719560400139±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	16.365401726216078±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	11±2
# 	Nvidia GeForce GTX 1080 Ti GPU	0.6084406139998464±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	154.81463638500009±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	110.70511864100081±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	135.7366089792922±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	100±10
# 	Nvidia GeForce GTX 1080 Ti GPU	16.97086323199983±0.0
# test_public_ams_no_tta:	3.79±0.01
# test_public_ams_mean_no_tta:	3.81±0.01
# test_public_ams_mean:	3.82±0.02
# test_public_ams:	3.8±0.01

# %%
swish_ensemble_embed_aug_onecycle_dense.print_table_row(swish_ensemble_embed_aug_onecycle)
# Out:
# $3.95\pm0.04$ & $3.89\pm0.05$ & $3.82\pm0.02$ & $0.09\pm0.03$ & $-0.02\pm0.09$\\

# %%
swish_ensemble_embed_aug_onecycle_dense.print_table_row(relu_ensemble)
# Out:
# $3.95\pm0.04$ & $3.89\pm0.05$ & $3.82\pm0.02$ & $0.81\pm0.08$ & $17\pm5$\\

# %%
swish_ensemble_embed_aug_onecycle_dense.plot()

# %%
swish_ensemble_embed_aug_onecycle_dense.compare_to(swish_ensemble_embed_aug_onecycle)
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	49.82905957853435±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	19.212634394020437±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	17.1882185550023±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	17.97±0.08 %
# 	Nvidia GeForce GTX 1080 Ti GPU	13.155299197913582±0.0 %
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	23.126283276542082±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	17.404878039534164±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	8.047593997208363±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	9.7±0.8 %
# 	Nvidia GeForce GTX 1080 Ti GPU	7.555243972961922±0.0 %
# val_ams_smooth_no_tta:	0.36±0.08 %
# val_ams_smooth:	1.1±0.07 %
# val_ams_max_no_tta:	-0.48±0.08 %
# val_ams_max:	-2.17±0.08 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	5.31635805058821±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	7.413018374126586±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1.8663000611233636±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±200 %
# 	Nvidia GeForce GTX 1080 Ti GPU	22.156943639629155±0.0 %
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	35.34320491104985±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	19.14356674493898±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-20.544551175859933±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-22±2 %
# 	Nvidia GeForce GTX 1080 Ti GPU	8.550429140637133±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	24.019852574063748±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	6.57939614287675±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-21.103622934324072±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-20±20 %
# 	Nvidia GeForce GTX 1080 Ti GPU	2.561789509642051±0.0 %
# test_public_ams_no_tta:	0.24±0.02 %
# test_public_ams_mean_no_tta:	0.11±0.02 %
# test_public_ams_mean:	0.21±0.03 %
# test_public_ams:	0.34±0.02 %

# %% [markdown]
# # 29 split

# %%
swish_ensemble_embed_aug_onecycle_dense_split = Result('29_swish_ensemble_embed_aug_onecycle_dense_split', RESULTS_PATH, is_blind=BLIND)

# %%
swish_ensemble_embed_aug_onecycle_dense_split
# Out:
# Experiment:	29_swish_ensemble_embed_aug_onecycle_dense_split
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
swish_ensemble_embed_aug_onecycle_dense_split.print_results()
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1.5591062040002726±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	0.8154293890002009±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1.176948050968349±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0.92±0.1
# 	Nvidia GeForce GTX 1080 Ti GPU	0.18000780200009103±0.0
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	16.28553424800066±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	9.42261038200013±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	14.282221325673163±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	11.6±0.2
# 	Nvidia GeForce GTX 1080 Ti GPU	4.590399506999802±0.0
# val_ams_smooth_no_tta:	3.62±0.05
# val_ams_smooth:	3.64±0.06
# val_ams_max_no_tta:	3.68±0.06
# val_ams_max:	3.69±0.06
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1053.6034661179992±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	765.7443097990003±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1369.6323183849454±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1600±200
# 	Nvidia GeForce GTX 1080 Ti GPU	752.099297273±0.0
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	19.13917879699966±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	10.986477577999722±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	12.152439087629318±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	9±1
# 	Nvidia GeForce GTX 1080 Ti GPU	0.481238360000134±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	157.1310017199994±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	90.7469076729999±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	112.73063417617232±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	81±6
# 	Nvidia GeForce GTX 1080 Ti GPU	16.391259310999885±0.0
# test_public_ams_no_tta:	3.578±0.01
# test_public_ams_mean_no_tta:	3.599±0.007
# test_public_ams_mean:	3.596±0.006
# test_public_ams:	3.576±0.007

# %%
swish_ensemble_embed_aug_onecycle_dense_split.print_table_row(swish_ensemble_embed_aug_onecycle_dense)
# Out:
# $3.69\pm0.06$ & $3.64\pm0.06$ & $3.596\pm0.006$ & $0.02\pm0.03$ & $-0.1\pm0.04$\\

# %%
swish_ensemble_embed_aug_onecycle_dense_split.plot()

# %%
swish_ensemble_embed_aug_onecycle_dense_split.compare_to(swish_ensemble_embed_aug_onecycle_dense)
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-6.515722111453568±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-4.9286799822760194±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-18.653869554984915±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-8.2±0.7 %
# 	Nvidia GeForce GTX 1080 Ti GPU	30.427512566757187±0.0 %
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	0.3330071966800687±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-7.819416052676853±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-11.34173292826498±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-6.5±0.6 %
# 	Nvidia GeForce GTX 1080 Ti GPU	3.5978237362808243±0.0 %
# val_ams_smooth_no_tta:	-6.2±0.1 %
# val_ams_smooth:	-6.4±0.1 %
# val_ams_max_no_tta:	-6.5±0.1 %
# val_ams_max:	-6.6±0.1 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-2.140971278088543±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-1.048796040929634±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-0.35210013403058277±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±300 %
# 	Nvidia GeForce GTX 1080 Ti GPU	12.435709865201472±0.0 %
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	2.747147136539489±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-19.259795348506703±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-25.743105540989728±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-16±4 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-20.906272703180285±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1.496218567628758±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-18.02826392582825±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-16.948983016534367±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-20±10 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-3.415288386197451±0.0 %
# test_public_ams_no_tta:	-5.56±0.02 %
# test_public_ams_mean_no_tta:	-5.64±0.02 %
# test_public_ams_mean:	-5.95±0.03 %
# test_public_ams:	-5.88±0.03 %

# %% [markdown]
# # 30 split bottleneck

# %%
swish_ensemble_embed_aug_onecycle_dense_split_bottleneck = Result('30_swish_ensemble_embed_aug_onecycle_dense_split_bottleneck', RESULTS_PATH, is_blind=BLIND)

# %%
swish_ensemble_embed_aug_onecycle_dense_split_bottleneck
# Out:
# Experiment:	30_swish_ensemble_embed_aug_onecycle_dense_split_bottleneck
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
swish_ensemble_embed_aug_onecycle_dense_split_bottleneck.print_results()
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1.8697445759989932±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	0.9323783920008282±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1.4487909795716405±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1.09±0.06
# 	Nvidia GeForce GTX 1080 Ti GPU	0.2244712489991798±0.0
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	18.220853327999066±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	10.472329423999327±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	16.505559476092458±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	13.2±0.6
# 	Nvidia GeForce GTX 1080 Ti GPU	4.970377761999771±0.0
# val_ams_smooth_no_tta:	3.72±0.05
# val_ams_smooth:	3.72±0.05
# val_ams_max_no_tta:	3.79±0.05
# val_ams_max:	3.8±0.05
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1114.8301140969998±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	859.7780620960002±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1520.7957883337513±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1800±200
# 	Nvidia GeForce GTX 1080 Ti GPU	882.4769959060004±0.0
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	22.456809962999614±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	12.576112990000183±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	14.587382912635803±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	11±2
# 	Nvidia GeForce GTX 1080 Ti GPU	0.5462382810001145±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	185.47837078699922±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	109.58015151299878±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	122.42532790452242±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	90±10
# 	Nvidia GeForce GTX 1080 Ti GPU	16.88894467800037±0.0
# test_public_ams_no_tta:	3.626±0.004
# test_public_ams_mean_no_tta:	3.64±0.004
# test_public_ams_mean:	3.647±0.006
# test_public_ams:	3.634±0.008

# %%
swish_ensemble_embed_aug_onecycle_dense_split_bottleneck.print_table_row(swish_ensemble_embed_aug_onecycle_dense)
# Out:
# $3.8\pm0.05$ & $3.72\pm0.05$ & $3.647\pm0.006$ & $0.14\pm0.05$ & $0.0\pm0.05$\\

# %%
swish_ensemble_embed_aug_onecycle_dense_split_bottleneck.plot()

# %%
swish_ensemble_embed_aug_onecycle_dense_split_bottleneck.compare_to(swish_ensemble_embed_aug_onecycle_dense)
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	12.110208448161464±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	8.706462729049115±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	0.13486994165150307±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	9.1±0.7 %
# 	Nvidia GeForce GTX 1080 Ti GPU	62.6442094421074±0.0 %
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	12.256250255481847±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	2.449894716763093±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	2.459853186096715±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	6.2±0.8 %
# 	Nvidia GeForce GTX 1080 Ti GPU	12.17331269428538±0.0 %
# val_ams_smooth_no_tta:	-3.66±0.08 %
# val_ams_smooth:	-4.31±0.09 %
# val_ams_max_no_tta:	-3.76±0.1 %
# val_ams_max:	-3.88±0.08 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	3.545779473785257±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	11.102457169191553±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	10.64583129227611±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±300 %
# 	Nvidia GeForce GTX 1080 Ti GPU	31.92663233985934±0.0 %
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	20.557584103208292±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-7.577480650737484±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-10.86449842983096±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-1±3 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-10.223238154800033±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	19.806741221639513±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-1.0161834807748293±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-9.806699294219547±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-10±20 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-0.48270116186543915±0.0 %
# test_public_ams_no_tta:	-4.31±0.02 %
# test_public_ams_mean_no_tta:	-4.58±0.02 %
# test_public_ams_mean:	-4.61±0.03 %
# test_public_ams:	-4.36±0.02 %

# %%
swish_ensemble_embed_aug_onecycle_dense_split_bottleneck.compare_to(swish_ensemble_embed_aug_onecycle_dense_split)
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	19.924131608334385±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	14.342014719878884±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	23.097275056416404±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	19±2 %
# 	Nvidia GeForce GTX 1080 Ti GPU	24.700844355105392±0.0 %
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	11.883669583857852±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	11.140427115658513±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	15.567173338944894±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	13.5±0.7 %
# 	Nvidia GeForce GTX 1080 Ti GPU	8.277672878374712±0.0 %
# val_ams_smooth_no_tta:	2.74±0.08 %
# val_ams_smooth:	2.27±0.08 %
# val_ams_max_no_tta:	2.9±0.08 %
# val_ams_max:	2.89±0.09 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	5.811166150068775±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	12.28004584476543±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	11.036791985680951±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±300 %
# 	Nvidia GeForce GTX 1080 Ti GPU	17.335170915028172±0.0 %
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	17.334239891839257±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	14.469017942417558±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	20.03666759774305±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	18±3 %
# 	Nvidia GeForce GTX 1080 Ti GPU	13.506803780139727±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	18.040595908319602±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	20.75359295752882±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	8.599875090917614±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	10±10 %
# 	Nvidia GeForce GTX 1080 Ti GPU	3.0362851173155305±0.0 %
# test_public_ams_no_tta:	1.32±0.01 %
# test_public_ams_mean_no_tta:	1.117±0.009 %
# test_public_ams_mean:	1.416±0.008 %
# test_public_ams:	1.61±0.01 %

# %% [markdown]
# # 32 wide-deep

# %%
swish_ensemble_embed_aug_onecycle_dense_wide_deep = Result('32_swish_ensemble_embed_aug_onecycle_dense_wide-deep', RESULTS_PATH, is_blind=BLIND)

# %%
swish_ensemble_embed_aug_onecycle_dense_wide_deep
# Out:
# Experiment:	32_swish_ensemble_embed_aug_onecycle_dense_wide-deep
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
swish_ensemble_embed_aug_onecycle_dense_wide_deep.print_results()
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	2.3950169820000156±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1.0499610699998811±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1.9125734890003514±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1.18±0.1
# 	Nvidia GeForce GTX 1080 Ti GPU	0.17701250999971307±0.0
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	22.183288905000154±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	11.847810945999754±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	18.462191264000467±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	12.9±0.8
# 	Nvidia GeForce GTX 1080 Ti GPU	4.609838209999907±0.0
# val_ams_smooth_no_tta:	3.85±0.06
# val_ams_smooth:	3.86±0.05
# val_ams_max_no_tta:	3.94±0.05
# val_ams_max:	3.93±0.05
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1278.690850268±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	867.9754893089998±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1488.2712113350008±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1600±100
# 	Nvidia GeForce GTX 1080 Ti GPU	772.4753432450001±0.0
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	26.879604062999988±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	12.33127305700009±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	17.169400746000065±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	9.4±0.2
# 	Nvidia GeForce GTX 1080 Ti GPU	0.6378225670000575±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	225.13654136700006±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	104.83746549599982±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	145.52075960500042±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	84±5
# 	Nvidia GeForce GTX 1080 Ti GPU	17.224843406999753±0.0
# test_public_ams_no_tta:	3.78±0.02
# test_public_ams_mean_no_tta:	3.8±0.02
# test_public_ams_mean:	3.82±0.02
# test_public_ams:	3.8±0.02

# %%
swish_ensemble_embed_aug_onecycle_dense_wide_deep.print_table_row(swish_ensemble_embed_aug_onecycle_dense)
# Out:
# $3.93\pm0.05$ & $3.86\pm0.05$ & $3.82\pm0.02$ & $0.12\pm0.02$ & $0.1\pm0.1$\\

# %%
swish_ensemble_embed_aug_onecycle_dense_wide_deep.plot()

# %%
swish_ensemble_embed_aug_onecycle_dense_wide_deep.compare_to(swish_ensemble_embed_aug_onecycle_dense)
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	43.605632841826676±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	22.415485925153472±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	32.189736321747084±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	19±1 %
# 	Nvidia GeForce GTX 1080 Ti GPU	28.25722616428111±0.0 %
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	36.66828803142643±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	15.906111706161527±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	14.605833818785056±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	3±1 %
# 	Nvidia GeForce GTX 1080 Ti GPU	4.036523532234534±0.0 %
# val_ams_smooth_no_tta:	-0.3±0.08 %
# val_ams_smooth:	-0.9±0.07 %
# val_ams_max_no_tta:	0.12±0.08 %
# val_ams_max:	-0.47±0.07 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	18.765217339183845±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	12.161747172020403±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	8.279498555782087±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±200 %
# 	Nvidia GeForce GTX 1080 Ti GPU	15.48184380179018±0.0 %
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	44.30099968896976±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-9.376822264729533±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	4.912797334489164±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-14±3 %
# 	Nvidia GeForce GTX 1080 Ti GPU	4.829058469166966±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	45.423292412172366±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-5.300254601622222±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	7.208188490402662±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-10±10 %
# 	Nvidia GeForce GTX 1080 Ti GPU	1.4965660351385404±0.0 %
# test_public_ams_no_tta:	-0.2±0.02 %
# test_public_ams_mean_no_tta:	-0.35±0.02 %
# test_public_ams_mean:	-0.2±0.02 %
# test_public_ams:	-0.06±0.02 %

# %%
swish_ensemble_embed_aug_onecycle_dense_wide_deep.compare_to(swish_ensemble_embed_aug_onecycle_dense_split_bottleneck)
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	28.09327074637307±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	12.611047082153801±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	32.01169222946405±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	8.7±0.5 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-21.142457758427735±0.0 %
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	21.74670694984528±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	13.134437108598313±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	11.854380281638438±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-2±1 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-7.253765594162909±0.0 %
# val_ams_smooth_no_tta:	3.49±0.08 %
# val_ams_smooth:	3.56±0.09 %
# val_ams_max_no_tta:	4.03±0.09 %
# val_ams_max:	3.55±0.09 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	14.698269637587403±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	0.9534352613063449±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-2.138655120447552±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±300 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-12.465101432821651±0.0 %
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	19.694667707868913±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-1.9468649271422485±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	17.700350013624995±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-13±3 %
# 	Nvidia GeForce GTX 1080 Ti GPU	16.766361711643523±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	21.381560778072465±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-4.328052071032559±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	18.864913082764836±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-10±10 %
# 	Nvidia GeForce GTX 1080 Ti GPU	1.988867483454579±0.0 %
# test_public_ams_no_tta:	4.3±0.02 %
# test_public_ams_mean_no_tta:	4.44±0.02 %
# test_public_ams_mean:	4.63±0.02 %
# test_public_ams:	4.5±0.02 %

# %% [markdown]
# # 33 search 4-100-0.1

# %%
search_4_100_01 = Result('33_search_4-100-0.1', RESULTS_PATH, is_blind=BLIND)

# %%
search_4_100_01
# Out:
# Experiment:	33_search_4-100-0.1
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
search_4_100_01.print_results()
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	2.6186112279992813±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1.526339280000684±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	2.5020398190099513±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1.49±0.04
# 	Nvidia GeForce GTX 1080 Ti GPU	0.15152517299975443±0.0
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	24.54974921700159±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	14.536431892998735±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	23.940268588994513±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	16.0±0.1
# 	Nvidia GeForce GTX 1080 Ti GPU	4.492241325999203±0.0
# val_ams_smooth_no_tta:	3.83±0.05
# val_ams_smooth:	3.83±0.05
# val_ams_max_no_tta:	3.9±0.04
# val_ams_max:	3.9±0.05
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1529.7670461270009±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	992.1732322419994±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1832.2472960099985±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1800±200
# 	Nvidia GeForce GTX 1080 Ti GPU	607.2124028120015±0.0
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	30.093723071000568±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	24.085233081001206±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	31.038865236012498±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	17.5±0.5
# 	Nvidia GeForce GTX 1080 Ti GPU	0.844476833999579±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	260.27432170500106±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	181.72902838799928±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	257.6265865829919±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	148.4±0.2
# 	Nvidia GeForce GTX 1080 Ti GPU	18.770828736000112±0.0
# test_public_ams_no_tta:	3.705±0.007
# test_public_ams_mean_no_tta:	3.73±0.01
# test_public_ams_mean:	3.74±0.01
# test_public_ams:	3.716±0.006

# %%
search_4_100_01.print_table_row(swish_ensemble_embed_aug_onecycle_dense)
# Out:
# $3.9\pm0.05$ & $3.83\pm0.05$ & $3.74\pm0.01$ & $0.23\pm0.09$ & $0.6\pm0.1$\\

# %%
search_4_100_01.plot()

# %%
search_4_100_01.compare_to(swish_ensemble_embed_aug_onecycle_dense)
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	57.01238253831606±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	77.95665952448482±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	72.93138582314444±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	49±4 %
# 	Nvidia GeForce GTX 1080 Ti GPU	9.789971245777078±0.0 %
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	51.24773479067826±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	42.20865833175622±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	48.61152743213806±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	28±1 %
# 	Nvidia GeForce GTX 1080 Ti GPU	1.3825538195627765±0.0 %
# val_ams_smooth_no_tta:	-0.71±0.07 %
# val_ams_smooth:	-1.69±0.08 %
# val_ams_max_no_tta:	-1.08±0.08 %
# val_ams_max:	-1.22±0.07 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	42.08525514475659±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	28.210859173186027±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	33.305554075851035±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±300 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-9.224276905100904±0.0 %
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	61.555739933162165±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	77.00365146451337±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	89.6614929182624±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	60±10 %
# 	Nvidia GeForce GTX 1080 Ti GPU	38.793633194215424±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	68.11997094237203±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	64.15594023011508±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	89.79889693744673±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	50±10 %
# 	Nvidia GeForce GTX 1080 Ti GPU	10.606210652893095±0.0 %
# test_public_ams_no_tta:	-2.23±0.01 %
# test_public_ams_mean_no_tta:	-2.12±0.02 %
# test_public_ams_mean:	-2.06±0.02 %
# test_public_ams:	-2.2±0.02 %

# %% [markdown]
# # 33 search 4-40-0.45

# %%
search_4_40_45 = Result('33_search_4-40-0.45', RESULTS_PATH, is_blind=BLIND)

# %%
search_4_40_45
# Out:
# Experiment:	33_search_4-40-0.45
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
search_4_40_45.print_results()
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1.4019755120025366±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	0.8678051419992698±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1.3758756659954088±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0.85±0.03
# 	Nvidia GeForce GTX 1080 Ti GPU	0.12178810200020962±0.0
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	14.331230191000941±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	9.894514050996804±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	15.634808551010792±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	12.0±0.3
# 	Nvidia GeForce GTX 1080 Ti GPU	4.165335206000236±0.0
# val_ams_smooth_no_tta:	3.9±0.05
# val_ams_smooth:	3.9±0.05
# val_ams_max_no_tta:	3.98±0.04
# val_ams_max:	3.96±0.05
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1247.1352760360005±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	737.0769552929996±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1347.3454537329962±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1400±100
# 	Nvidia GeForce GTX 1080 Ti GPU	602.0097012280003±0.0
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	17.123354606002977±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	13.113071751999087±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	16.940809714011266±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	9.5±0.4
# 	Nvidia GeForce GTX 1080 Ti GPU	0.5421480609984428±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	157.0049859139981±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	107.61457865400007±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	146.64317745200242±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	85±2
# 	Nvidia GeForce GTX 1080 Ti GPU	16.547418146999917±0.0
# test_public_ams_no_tta:	3.79±0.01
# test_public_ams_mean_no_tta:	3.83±0.01
# test_public_ams_mean:	3.82±0.01
# test_public_ams:	3.78±0.009

# %%
search_4_40_45.print_table_row(swish_ensemble_embed_aug_onecycle_dense)
# Out:
# $3.96\pm0.05$ & $3.9\pm0.05$ & $3.82\pm0.01$ & $-0.02\pm0.05$ & $-0.01\pm0.03$\\

# %%
search_4_40_45.plot()

# %%
search_4_40_45.compare_to(swish_ensemble_embed_aug_onecycle_dense)
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-15.937305604513277±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1.1778352374526162±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-4.904756577744324±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-15±1 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-11.756495953959744±0.0 %
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-11.707199776543803±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-3.202823196614822±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-2.9454172062672694±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-3.0±0.6 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-5.995183683746401±0.0 %
# val_ams_smooth_no_tta:	0.92±0.07 %
# val_ams_smooth:	0.21±0.07 %
# val_ams_max_no_tta:	1.16±0.08 %
# val_ams_max:	0.21±0.07 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	15.834325457740649±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-4.753256141240203±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-1.9735858622460425±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±200 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-10.002059104785179±0.0 %
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-8.074643440295542±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-3.6313423160978098±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	3.5160028297590156±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-13±3 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-10.895484534735598±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1.4148207043880219±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-2.791686622027723±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	8.035097203860527±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-10±10 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-2.495129913023368±0.0 %
# test_public_ams_no_tta:	0.07±0.02 %
# test_public_ams_mean_no_tta:	0.31±0.02 %
# test_public_ams_mean:	-0.19±0.02 %
# test_public_ams:	-0.5±0.02 %

# %% [markdown]
# # 33 search 5-100--0.1

# %%
search_5_100_n01 = Result('33_search_5-100--0.1', RESULTS_PATH, is_blind=BLIND)

# %%
search_5_100_n01
# Out:
# Experiment:	33_search_5-100--0.1
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
search_5_100_n01.print_results()
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	2.810940948998905±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1.4480512619993533±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	2.5343201999930898±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1.5±0.2
# 	Nvidia GeForce GTX 1080 Ti GPU	0.1420271919996594±0.0
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	26.586594525997498±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	14.370215187002032±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	24.09257189699565±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	16.7±0.2
# 	Nvidia GeForce GTX 1080 Ti GPU	4.85423656799685±0.0
# val_ams_smooth_no_tta:	3.88±0.05
# val_ams_smooth:	3.91±0.05
# val_ams_max_no_tta:	4.05±0.07
# val_ams_max:	4.03±0.05
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1465.0106742099997±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	929.3762820730044±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1621.749973959988±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1600±100
# 	Nvidia GeForce GTX 1080 Ti GPU	632.8225290120026±0.0
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	33.50669378300154±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	23.237813961997745±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	30.02323482099746±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	16.7±0.3
# 	Nvidia GeForce GTX 1080 Ti GPU	0.7920819740029401±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	288.20411590599906±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	189.58636449699407±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	251.299958566±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	143±2
# 	Nvidia GeForce GTX 1080 Ti GPU	19.129222354000376±0.0
# test_public_ams_no_tta:	3.777±0.009
# test_public_ams_mean_no_tta:	3.8±0.01
# test_public_ams_mean:	3.8±0.02
# test_public_ams:	3.78±0.02

# %%
search_5_100_n01.print_table_row(swish_ensemble_embed_aug_onecycle_dense)
# Out:
# $4.03\pm0.05$ & $3.91\pm0.05$ & $3.8\pm0.02$ & $0.15\pm0.07$ & $0.6\pm0.1$\\

# %%
search_5_100_n01.plot()

# %%
search_5_100_n01.compare_to(swish_ensemble_embed_aug_onecycle_dense)
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	68.54450590362868±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	68.82902037711038±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	75.16248181766066±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	54±4 %
# 	Nvidia GeForce GTX 1080 Ti GPU	2.9080582259842562±0.0 %
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	63.79646742259051±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	40.58257464587593±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	49.55696491337925±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	34±2 %
# 	Nvidia GeForce GTX 1080 Ti GPU	9.552195528668637±0.0 %
# val_ams_smooth_no_tta:	0.47±0.07 %
# val_ams_smooth:	0.38±0.07 %
# val_ams_max_no_tta:	2.8±0.1 %
# val_ams_max:	1.9±0.07 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	36.070662498529586±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	20.096095870784392±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	17.99077522014444±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±200 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-5.395669792349795±0.0 %
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	79.87799960992722±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	70.77592355006885±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	83.45553212361793±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	50±10 %
# 	Nvidia GeForce GTX 1080 Ti GPU	30.182298120411154±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	86.16076789359886±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	71.2534766452784±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	85.1379376983979±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	50±10 %
# 	Nvidia GeForce GTX 1080 Ti GPU	12.718027907565716±0.0 %
# test_public_ams_no_tta:	-0.32±0.01 %
# test_public_ams_mean_no_tta:	-0.26±0.02 %
# test_public_ams_mean:	-0.57±0.03 %
# test_public_ams:	-0.62±0.02 %

# %% [markdown]
# # 33 search 5-33-0.9

# %%
search_5_33_09 = Result('33_search_5-33-0.9', RESULTS_PATH, is_blind=BLIND)

# %%
search_5_33_09
# Out:
# Experiment:	33_search_5-33-0.9
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
search_5_33_09.print_results()
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	2.8536005679998198±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1.4090870100001212±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	2.546703772008186±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1.57±0.07
# 	Nvidia GeForce GTX 1080 Ti GPU	0.15293990400004986±0.0
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	26.98066211999867±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	14.313122774000021±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	24.316251692012884±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	16.8±0.3
# 	Nvidia GeForce GTX 1080 Ti GPU	4.556545360999962±0.0
# val_ams_smooth_no_tta:	3.87±0.04
# val_ams_smooth:	3.89±0.04
# val_ams_max_no_tta:	3.96±0.06
# val_ams_max:	3.95±0.05
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	1533.3856254579987±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	961.356464453±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1648.514887133002±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1700±100
# 	Nvidia GeForce GTX 1080 Ti GPU	646.5083412590001±0.0
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	33.661898762999044±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	23.23686571600001±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	31.80993417801801±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	17.3±0.8
# 	Nvidia GeForce GTX 1080 Ti GPU	0.7942312710000579±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	307.06211962700036±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	184.7664329260001±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	256.2803500620066±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	145±3
# 	Nvidia GeForce GTX 1080 Ti GPU	18.652461158999927±0.0
# test_public_ams_no_tta:	3.77±0.01
# test_public_ams_mean_no_tta:	3.8±0.01
# test_public_ams_mean:	3.81±0.02
# test_public_ams:	3.78±0.02

# %%
search_5_33_09.print_table_row(swish_ensemble_embed_aug_onecycle_dense)
# Out:
# $3.95\pm0.05$ & $3.89\pm0.04$ & $3.81\pm0.02$ & $0.19\pm0.08$ & $0.6\pm0.2$\\

# %%
search_5_33_09.plot()

# %%
search_5_33_09.compare_to(swish_ensemble_embed_aug_onecycle_dense)
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	71.10238404372512±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	64.28615876206338±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	76.01838676918887±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	57±5 %
# 	Nvidia GeForce GTX 1080 Ti GPU	10.815037066643665±0.0 %
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	66.22426537768382±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	40.02404449805824±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	50.94547882539525±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	35±2 %
# 	Nvidia GeForce GTX 1080 Ti GPU	2.8337909228654294±0.0 %
# val_ams_smooth_no_tta:	0.29±0.07 %
# val_ams_smooth:	-0.15±0.07 %
# val_ams_max_no_tta:	0.49±0.09 %
# val_ams_max:	-0.02±0.07 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	42.42134995658304±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	24.22864704855527±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	19.938062351139454±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±200 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-3.3496979098438673±0.0 %
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	80.71120510349978±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	70.76895484009121±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	94.37307259656825±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	60±10 %
# 	Nvidia GeForce GTX 1080 Ti GPU	30.53554492012566±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	98.34178912088409±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	66.89962956922383±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	88.80709632366343±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	50±10 %
# 	Nvidia GeForce GTX 1080 Ti GPU	9.90873536609098±0.0 %
# test_public_ams_no_tta:	-0.52±0.02 %
# test_public_ams_mean_no_tta:	-0.46±0.02 %
# test_public_ams_mean:	-0.41±0.02 %
# test_public_ams:	-0.38±0.02 %

# %% [markdown]
# # 33 search 8-33-0.2

# %%
search_8_33_n02 = Result('33_search_8-33-0.2', RESULTS_PATH, is_blind=BLIND)

# %%
search_8_33_n02
# Out:
# Experiment:	33_search_8-33-0.2
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
search_8_33_n02.print_results()
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	4.635716564999711±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1.9241090200002873±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	3.343592314005946±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	2.1±0.1
# 	Nvidia GeForce GTX 1080 Ti GPU	0.17105517999971198±0.0
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	41.949090455999794±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	17.99402542399912±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	31.433926528989105±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	20.65±0.06
# 	Nvidia GeForce GTX 1080 Ti GPU	4.5371240849999595±0.0
# val_ams_smooth_no_tta:	3.86±0.06
# val_ams_smooth:	3.89±0.06
# val_ams_max_no_tta:	3.94±0.06
# val_ams_max:	3.95±0.06
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	2062.4668632680005±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1068.8437773990008±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1892.7562620819954±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	2000±200
# 	Nvidia GeForce GTX 1080 Ti GPU	735.7153361680002±0.0
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	60.09925137400023±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	30.847037131001343±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	40.14012787200045±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	21.9±0.7
# 	Nvidia GeForce GTX 1080 Ti GPU	0.9519018969995159±0.0
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	528.83171812±0.0
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	236.95850455000073±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	331.8928448880033±0.0
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	191±4
# 	Nvidia GeForce GTX 1080 Ti GPU	19.759684093999567±0.0
# test_public_ams_no_tta:	3.77±0.01
# test_public_ams_mean_no_tta:	3.8±0.02
# test_public_ams_mean:	3.82±0.02
# test_public_ams:	3.8±0.02

# %%
search_8_33_n02.print_table_row(swish_ensemble_embed_aug_onecycle_dense)
# Out:
# $3.95\pm0.06$ & $3.89\pm0.06$ & $3.82\pm0.02$ & $0.4\pm0.1$ & $1.2\pm0.4$\\

# %%
search_8_33_n02.plot()

# %%
search_8_33_n02.compare_to(swish_ensemble_embed_aug_onecycle_dense)
# Out:
# val_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	177.95836772572756±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	124.33283231761409±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	131.09626317516364±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	109±9 %
# 	Nvidia GeForce GTX 1080 Ti GPU	23.940748073853293±0.0 %
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	158.44275849487258±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	76.03399736402206±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	95.12913221074587±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	66±3 %
# 	Nvidia GeForce GTX 1080 Ti GPU	2.3954844258570778±0.0 %
# val_ams_smooth_no_tta:	-0.01±0.08 %
# val_ams_smooth:	-0.01±0.08 %
# val_ams_max_no_tta:	-0.06±0.09 %
# val_ams_max:	-0.01±0.08 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	91.5625854517924±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	38.118399659480964±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	37.70789718005415±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	0±300 %
# 	Nvidia GeForce GTX 1080 Ti GPU	9.986375975482607±0.0 %
# test_time_no_tta:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	222.63801332418186±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	126.69650697113762±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	145.2743204445702±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	100±20 %
# 	Nvidia GeForce GTX 1080 Ti GPU	56.44943402804406±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	241.59025946673233±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	114.0447591392948±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	144.51240338458464±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	100±20 %
# 	Nvidia GeForce GTX 1080 Ti GPU	16.432993560051845±0.0 %
# test_public_ams_no_tta:	-0.43±0.02 %
# test_public_ams_mean_no_tta:	-0.5±0.02 %
# test_public_ams_mean:	-0.11±0.03 %
# test_public_ams:	-0.09±0.03 %

# %% [markdown]
# # Baseline+cat

# %%
relu_baseline.results
# Out:
# {'val_ams_max': array([3.43249824, 0.0402922 ]),
#  'test_time': {'Intel Core i7-8559U CPU @ 2.7 GHz (4x2)': (1.0854913719995238,
#    nan),
#   'Intel Core i7-8700K CPU @ 3.7 GHz (6x2)': (0.8953697239994654, nan),
#   'Intel Xenon Skylake CPU @ 2.2 GHz (2x2)': (1.689862072467804, nan),
#   'Intel Xenon Skylake CPU @ 2.2 GHz (4x1)': (1.2474398389458656,
#    0.02263965830206871),
#   'Nvidia GeForce GTX 1080 Ti GPU': (0.14060635200075922, nan)},
#  'test_public_ams': array([3.42450174, 0.01757511]),
#  'train_time': {'Intel Core i7-8559U CPU @ 2.7 GHz (4x2)': (45.22926070699759,
#    nan),
#   'Intel Core i7-8700K CPU @ 3.7 GHz (6x2)': (42.750536903000466, nan),
#   'Intel Xenon Skylake CPU @ 2.2 GHz (2x2)': (67.40384469553828, nan),
#   'Intel Xenon Skylake CPU @ 2.2 GHz (4x1)': (78.81253574043512,
#    3.968005202710628),
#   'Nvidia GeForce GTX 1080 Ti GPU': (32.43193237400192, nan)},
#  'val_time': {'Intel Core i7-8559U CPU @ 2.7 GHz (4x2)': (0.14059407399690826,
#    nan),
#   'Intel Core i7-8700K CPU @ 3.7 GHz (6x2)': (0.08680325399836875, nan),
#   'Intel Xenon Skylake CPU @ 2.2 GHz (2x2)': (0.21408750489354134, nan),
#   'Intel Xenon Skylake CPU @ 2.2 GHz (4x1)': (0.15511046536266804,
#    0.002055266872048378),
#   'Nvidia GeForce GTX 1080 Ti GPU': (0.04273891499906313, nan)},
#  'val_ams_smooth': array([3.37697263, 0.04106728]),
#  'test_public_ams_mean': array([3.43594332, 0.01605986])}

# %%
baseline_cat = Result('38_baseline+cat', RESULTS_PATH, is_blind=BLIND)

# %%
baseline_cat
# Out:
# Experiment:	38_baseline+cat
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
results = {}
for r in baseline_cat.results:
    if '_no_tta' in r: results[r[:r.rfind('_no_tta')]] = baseline_cat.results[r]
    else: results[r] = baseline_cat.results[r]

# %%
baseline_cat.results = results

# %%
baseline_cat.print_table_row(relu_baseline)
# Out:
# $3.54\pm0.06$ & $3.5\pm0.06$ & $3.47\pm0.03$ & $0.19\pm0.06$ & $-0.1\pm0.1$\\

# %%
baseline_cat.plot()

# %%
baseline_cat.compare_to(relu_baseline)
# Out:
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	-4.8424338262127815±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-3.9549093383500047±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-10.42494505311128±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-1.26±0.02 %
# 	Nvidia GeForce GTX 1080 Ti GPU	37.00436476076937±0.0 %
# val_ams_smooth:	3.52±0.08 %
# val_ams_max:	3.17±0.08 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	12.398114794157946±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	14.89911019468982±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	38.79162722796495±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	5±4 %
# 	Nvidia GeForce GTX 1080 Ti GPU	21.492262661430964±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	7.9408235960255515±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-40.49922152606233±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-6.37037307193658±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-29.6±0.5 %
# 	Nvidia GeForce GTX 1080 Ti GPU	16.41407708169134±0.0 %
# test_public_ams_mean:	0.93±0.03 %
# test_public_ams:	0.72±0.03 %

# %% [markdown]
# # Baseline+swish

# %%
baseline_swish = Result('39_baseline+swish', RESULTS_PATH, is_blind=BLIND)

# %%
baseline_swish
# Out:
# Experiment:	39_baseline+swish
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
results = {}
for r in baseline_swish.results:
    if '_no_tta' in r: results[r[:r.rfind('_no_tta')]] = baseline_swish.results[r]
    else: results[r] = baseline_swish.results[r]

# %%
baseline_swish.results = results

# %%
baseline_swish.print_table_row(relu_baseline)
# Out:
# $3.53\pm0.04$ & $3.47\pm0.04$ & $3.49\pm0.02$ & $0.03\pm0.04$ & $0.1\pm0.2$\\

# %%
baseline_swish.plot()

# %%
baseline_swish.compare_to(relu_baseline)
# Out:
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	50.9135342394617±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-8.299190026524723±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	4.70617063274312±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	2.67±0.04 %
# 	Nvidia GeForce GTX 1080 Ti GPU	9.881029973143901±0.0 %
# val_ams_smooth:	2.9±0.07 %
# val_ams_max:	2.84±0.07 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	9.904114869401345±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	5.207911842256486±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-12.544791165289466±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	5±5 %
# 	Nvidia GeForce GTX 1080 Ti GPU	6.07605020963154±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	65.98071062333742±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-36.002935252205276±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	27.498072082076582±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-18.1±0.3 %
# 	Nvidia GeForce GTX 1080 Ti GPU	12.621907009573555±0.0 %
# test_public_ams_mean:	1.52±0.03 %
# test_public_ams:	1.39±0.03 %

# %% [markdown]
# # Baseline+onecycle

# %%
baseline_onecycle = Result('40_baseline+onecycle', RESULTS_PATH, is_blind=BLIND)

# %%
baseline_onecycle
# Out:
# Experiment:	40_baseline+onecycle
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
results = {}
for r in baseline_onecycle.results:
    if '_no_tta' in r: results[r[:r.rfind('_no_tta')]] = baseline_onecycle.results[r]
    else: results[r] = baseline_onecycle.results[r]

# %%
baseline_onecycle.results = results

# %%
baseline_onecycle.print_table_row(relu_baseline)
# Out:
# $3.55\pm0.03$ & $3.51\pm0.04$ & $3.51\pm0.01$ & $0.44\pm0.07$ & $-0.2\pm0.1$\\

# %%
baseline_onecycle.plot()

# %%
baseline_onecycle.compare_to(relu_baseline)
# Out:
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	31.85660798509826±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-13.669164981498852±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-16.808806995852713±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-11.3±0.1 %
# 	Nvidia GeForce GTX 1080 Ti GPU	-3.231155959658949±0.0 %
# val_ams_smooth:	3.82±0.07 %
# val_ams_max:	3.51±0.07 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	68.28102344424138±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	23.505763300235984±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	44.497630940517766±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	40±20 %
# 	Nvidia GeForce GTX 1080 Ti GPU	46.66040755909044±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	3.2875413772820545±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-50.05324381508615±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	-7.9502529145082175±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-33.8±0.6 %
# 	Nvidia GeForce GTX 1080 Ti GPU	5.267611949193536±0.0 %
# test_public_ams_mean:	2.23±0.02 %
# test_public_ams:	2.09±0.02 %

# %% [markdown]
# # Baseline+dense

# %%
baseline_dense = Result('41_baseline+dense', RESULTS_PATH, is_blind=BLIND)

# %%
baseline_dense
# Out:
# Experiment:	41_baseline+dense
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
results = {}
for r in baseline_dense.results:
    if '_no_tta' in r: results[r[:r.rfind('_no_tta')]] = baseline_dense.results[r]
    else: results[r] = baseline_dense.results[r]

# %%
baseline_dense.results = results

# %%
baseline_dense.print_table_row(relu_baseline)
# Out:
# $3.48\pm0.05$ & $3.44\pm0.03$ & $3.44\pm0.03$ & $0.25\pm0.08$ & $0.0\pm0.2$\\

# %%
baseline_dense.plot()

# %%
baseline_dense.compare_to(relu_baseline)
# Out:
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	54.063102976277094±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-2.9415878786780096±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	7.353307437371492±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	7.2±0.1 %
# 	Nvidia GeForce GTX 1080 Ti GPU	22.042365840912186±0.0 %
# val_ams_smooth:	1.73±0.06 %
# val_ams_max:	1.45±0.06 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	39.643617319236576±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	6.897863988679125±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	9.326331440977723±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	25±8 %
# 	Nvidia GeForce GTX 1080 Ti GPU	43.938319927000734±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	50.121207504244616±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	-35.077662621486624±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	4.87533272864365±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	-20.6±0.4 %
# 	Nvidia GeForce GTX 1080 Ti GPU	19.820522758811748±0.0 %
# test_public_ams_mean:	0.06±0.03 %
# test_public_ams:	0.01±0.03 %

# %% [markdown]
# # Baseline+aug

# %%
baseline_aug = Result('42_baseline+aug', RESULTS_PATH, is_blind=BLIND)

# %%
baseline_aug
# Out:
# Experiment:	42_baseline+aug
# Machines:
# 	daedalus
# 	helios_cpu
# 	helios_cuda
# 	icarus
# 	mbp
# 	morpheus

# %%
baseline_aug.results
# Out:
# {'test_public_ams_mean_no_tta': array([3.61551106, 0.02583699]),
#  'val_ams_max': array([3.73180166, 0.05033665]),
#  'test_public_ams_no_tta': array([3.59979664, 0.02453437]),
#  'test_time': {'Intel Core i7-8559U CPU @ 2.7 GHz (4x2)': (24.943821408000076,
#    nan),
#   'Intel Core i7-8700K CPU @ 3.7 GHz (6x2)': (16.247833714999615, nan),
#   'Intel Xenon Skylake CPU @ 2.2 GHz (2x2)': (31.701067063957453, nan),
#   'Intel Xenon Skylake CPU @ 2.2 GHz (4x1)': (22.502027622424066,
#    3.5426836544647813),
#   'Nvidia GeForce GTX 1080 Ti GPU': (13.785647895999318, nan)},
#  'test_public_ams': array([3.68126949, 0.01379817]),
#  'train_time': {'Intel Core i7-8559U CPU @ 2.7 GHz (4x2)': (163.12308006900003,
#    nan),
#   'Intel Core i7-8700K CPU @ 3.7 GHz (6x2)': (107.57158840800003, nan),
#   'Intel Xenon Skylake CPU @ 2.2 GHz (2x2)': (174.78701929189265, nan),
#   'Intel Xenon Skylake CPU @ 2.2 GHz (4x1)': (178.959220726043,
#    17.651901265606284),
#   'Nvidia GeForce GTX 1080 Ti GPU': (75.44352531500044, nan)},
#  'val_time': {'Intel Core i7-8559U CPU @ 2.7 GHz (4x2)': (4.816867650000859,
#    nan),
#   'Intel Core i7-8700K CPU @ 3.7 GHz (6x2)': (3.685174403000019, nan),
#   'Intel Xenon Skylake CPU @ 2.2 GHz (2x2)': (6.904023967683315, nan),
#   'Intel Xenon Skylake CPU @ 2.2 GHz (4x1)': (6.785535523667932,
#    0.1823642384260893),
#   'Nvidia GeForce GTX 1080 Ti GPU': (3.4113074679999045, nan)},
#  'val_ams_max_no_tta': array([3.68196279, 0.04344214]),
#  'val_ams_smooth_no_tta': array([3.61575779, 0.03602136]),
#  'val_time_no_tta': {'Intel Core i7-8559U CPU @ 2.7 GHz (4x2)': (0.1505894840001929,
#    nan),
#   'Intel Core i7-8700K CPU @ 3.7 GHz (6x2)': (0.0741142030001356, nan),
#   'Intel Xenon Skylake CPU @ 2.2 GHz (2x2)': (0.18675507977604866, nan),
#   'Intel Xenon Skylake CPU @ 2.2 GHz (4x1)': (0.13660641014575958,
#    0.00471060536801815),
#   'Nvidia GeForce GTX 1080 Ti GPU': (0.06006249399979424, nan)},
#  'val_ams_smooth': array([3.68196302, 0.05355474]),
#  'test_time_no_tta': {'Intel Core i7-8559U CPU @ 2.7 GHz (4x2)': (1.1821562840004844,
#    nan),
#   'Intel Core i7-8700K CPU @ 3.7 GHz (6x2)': (0.4991793540002618, nan),
#   'Intel Xenon Skylake CPU @ 2.2 GHz (2x2)': (1.554138096049428, nan),
#   'Intel Xenon Skylake CPU @ 2.2 GHz (4x1)': (0.8406104054301977,
#    0.05248859710991382),
#   'Nvidia GeForce GTX 1080 Ti GPU': (0.1548118290002094, nan)},
#  'test_public_ams_mean': array([3.70057295, 0.01551486])}

# %%
baseline_aug.print_table_row(relu_baseline)
# Out:
# $3.73\pm0.05$ & $3.68\pm0.05$ & $3.7\pm0.02$ & $1.7\pm0.2$ & $30\pm20$\\

# %%
baseline_aug.plot()

# %%
baseline_aug.compare_to(relu_baseline)
# Out:
# val_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	3326.081564509457±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	4145.433475419335±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	3124.8607741570245±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	4270±60 %
# 	Nvidia GeForce GTX 1080 Ti GPU	7881.736242192117±0.0 %
# val_ams_smooth:	9.0±0.1 %
# val_ams_max:	8.7±0.1 %
# train_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	260.6582940316834±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	151.62628636004348±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	159.3131298094372±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	130±20 %
# 	Nvidia GeForce GTX 1080 Ti GPU	132.62112304932367±0.0 %
# test_time:
# 	Intel Core i7-8559U CPU @ 2.7 GHz (4x2)	2197.9290348528925±0.0 %
# 	Intel Core i7-8700K CPU @ 3.7 GHz (6x2)	1714.6507838597986±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (2x2)	1775.9558889716093±0.0 %
# 	Intel Xenon Skylake CPU @ 2.2 GHz (4x1)	1700±30 %
# 	Nvidia GeForce GTX 1080 Ti GPU	9704.427538184676±0.0 %
# test_public_ams_mean:	7.7±0.04 %
# test_public_ams:	7.5±0.04 %

# %% [markdown]
# # Plot

# %%
relu_baseline.exp_name = '1_relu'
swish_ensemble_embed_aug_swaconst.exp_name = '11_swish_ensemble_embed_aug_swa'

# %%
exp_comp = ExpComp([relu_baseline, relu_ensemble,
                    relu_ensemble_embed, relu_ensemble_embed_fix, relu_ensemble_embed_aug,
                    relu_ensemble_embed_aug_cosine,
                    swish_ensemble_embed_aug_cosine,
                    swish_ensemble_embed_aug_swaconst,
                    swish_ensemble_embed_aug_onecycle,
                    swish_ensemble_embed_aug_onecycle_dense])

# %%
exp_comp.plot_ams(False, savename='plots/ams_evo')

# %%
exp_comp.plot_time(savename='plots/abs')

# %%
exp_comp.plot_time(delta=True, frac=True, savename='plots/rel')

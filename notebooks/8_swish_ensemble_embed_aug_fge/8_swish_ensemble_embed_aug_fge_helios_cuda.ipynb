# %% [markdown]
# # Swish-based ensemble with categorical entity embedding
# - SWish activation, 4 layers, 100 neurons per layer
# - PRI_jet_num embedded
# - Train-time/test-time data augmentation
# - linear cycle LR
# - FGE
# - Validation score use ensemble of 10 models weighted by loss

# %% [markdown]
# ### Import modules

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
from __future__ import division
import sys
import os
sys.path.append('../../')
from modules.basics import *
# Out:
# /home/giles/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
NAME = '8_swish_ensemble_embed_aug_fge'

# %%
experiment = Experiment(NAME, 'helios_cuda', RESULTS_PATH)

# %%
# !python ../../modules/data_import.py -d ../../data/ -f PRI_jet_num -s {experiment.seed}
# Out:
# /home/giles/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Converting to use_cartesian coordinates
# Converting to use_cartesian coordinates
# Training on 200000 datapoints and validating on 50000, using 31 feats:
# ['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet', 'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt', 'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality', 'DER_lep_eta_centrality', 'PRI_met_sumet', 'PRI_jet_num', 'PRI_jet_all_pt', 'PRI_jet_leading_px', 'PRI_jet_leading_py', 'PRI_jet_leading_pz', 'PRI_met_px', 'PRI_met_py', 'PRI_tau_px', 'PRI_tau_py', 'PRI_tau_pz', 'PRI_jet_subleading_px', 'PRI_jet_subleading_py', 'PRI_jet_subleading_pz', 'PRI_lep_px', 'PRI_lep_py', 'PRI_lep_pz', 'PRI_met_pt']
# Saving fold 0 with 20003 events
# Saving fold 1 with 20003 events
# Saving fold 2 with 20003 events
# Saving fold 3 with 20003 events
# Saving fold 4 with 20002 events
# Saving fold 5 with 20001 events
# Saving fold 6 with 19999 events
# Saving fold 7 with 19996 events
# Saving fold 8 with 19995 events
# Saving fold 9 with 19995 events
# Saving fold 0 with 5003 events
# Saving fold 1 with 5003 events
# Saving fold 2 with 5002 events
# Saving fold 3 with 5002 events
# Saving fold 4 with 5001 events
# Saving fold 5 with 5001 events
# Saving fold 6 with 5000 events
# Saving fold 7 with 4997 events
# Saving fold 8 with 4996 events
# Saving fold 9 with 4995 events
# gen_strat_key not found in DataFrame
# Saving fold 0 with 55000 events
# Saving fold 1 with 55000 events
# Saving fold 2 with 55000 events
# Saving fold 3 with 55000 events
# Saving fold 4 with 55000 events
# Saving fold 5 with 55000 events
# Saving fold 6 with 55000 events
# Saving fold 7 with 55000 events
# Saving fold 8 with 55000 events
# Saving fold 9 with 55000 events

# %% [markdown]
# ## Training

# %% [markdown]
# ### Import data

# %%
train_fy = HEPAugFoldYielder(DATA_PATH/'train.hdf5', rot_mult=2)
# Out:
# Augmenting via phi rotations
# Augmenting via y flips
# Augmenting via longitunidnal flips
# Total augmentation multiplicity is 8

# %%
train_feats = train_fy.cont_feats+train_fy.cat_feats

# %%
id=3
aug_ranges = [range(4), range(4,8)]
for aug_range in aug_ranges:
    compare_events([pd.DataFrame(train_fy.get_test_fold(0, i)['inputs'], columns=train_feats)[id:id+1] for i in aug_range])
# Out:
# /home/giles/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# /home/giles/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
id=3
compare_events([pd.DataFrame(train_fy.get_fold(0)['inputs'], columns=train_feats)[id:id+1] for i in range(4)])
# Out:
# /home/giles/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %% [markdown]
# ### Options

# %%
n_models = 10
patience = 10
max_epochs = 200
ensemble_size = 10


bs = 256
objective = 'classification'
model_args = {'body':{'act':'swish', 'width':100, 'depth':4}}
opt_args = {'opt':'adam', 'eps':1e-08}
cat_embedder = CatEmbedder.from_fy(train_fy, emb_szs=[3])

n_out = 1
model_builder = ModelBuilder(objective, cont_feats=train_fy.cont_feats, n_out=n_out, cat_embedder=cat_embedder,
                             model_args=model_args, opt_args=opt_args)
Model(model_builder)
# Out:
# Inputs:
# 30 Continuous: ['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet', 'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt', 'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality', 'DER_lep_eta_centrality', 'PRI_met_sumet', 'PRI_jet_all_pt', 'PRI_jet_leading_px', 'PRI_jet_leading_py', 'PRI_jet_leading_pz', 'PRI_met_px', 'PRI_met_py', 'PRI_tau_px', 'PRI_tau_py', 'PRI_tau_pz', 'PRI_jet_subleading_px', 'PRI_jet_subleading_py', 'PRI_jet_subleading_pz', 'PRI_lep_px', 'PRI_lep_py', 'PRI_lep_pz', 'PRI_met_pt']
#
# 1  Categorical: ['PRI_jet_num']
#
# 0  Matrix elements: []
#
#
# Model:
# <bound method Module.parameters of Sequential(
#   (0): CatEmbHead(
#     (embeds): ModuleList(
#       (0): Embedding(4, 3)
#     )
#   )
#   (1): FullyConnected(
#     (layers): Sequential(
#       (0): Sequential(
#         (0): Linear(in_features=33, out_features=100, bias=True)
#         (1): Swish()
#       )
#       (1): Sequential(
#         (0): Linear(in_features=100, out_features=100, bias=True)
#         (1): Swish()
#       )
#       (2): Sequential(
#         (0): Linear(in_features=100, out_features=100, bias=True)
#         (1): Swish()
#       )
#       (3): Sequential(
#         (0): Linear(in_features=100, out_features=100, bias=True)
#         (1): Swish()
#       )
#     )
#   )
#   (2): ClassRegMulti(
#     (dense): Linear(in_features=100, out_features=1, bias=True)
#     (act): Sigmoid()
#   )
# )>
#
#
# Number of trainable parameters: 33813
#
#
# Optimiser:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
#
#
# Loss:
# <class 'torch.nn.modules.loss.BCELoss'>

# %% [markdown]
# ### Determine LR

# %%
lr_finder = fold_lr_find(train_fy, model_builder, 256, lr_bounds=[1e-5,1e1])
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10/10 00:03<00:00]
#     </div>
# LR finder took 3.760s

# %% [markdown]
# ### Train classifier

# %%
callback_partials = [partial(CycleLR, lr_range=(2e-4, 2e-3), cycle_mult=1 ,scale=5, interp='linear')]
eval_metrics = {'AMS':AMS(n_total=250000, br=10, wgt_name='gen_weight_original')}

# %%
train_timer = timeit.default_timer()
results, histories, cycle_losses = fold_train_ensemble(train_fy, n_models,
                                                       model_builder=model_builder,
                                                       bs=bs,
                                                       callback_partials=callback_partials,
                                                       eval_metrics=eval_metrics,
                                                       max_epochs=max_epochs, patience=patience)
train_time = timeit.default_timer()-train_timer
experiment['train_time'] = train_time
# Out:
# Training model 1 / 10, Val ID = 0
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Early stopping after 280 epochs
# Scores are: {'loss': 3.1815486636332935e-06, 'AMS': 3.699639729527827}
# Fold took 128.896s
#
# Training model 2 / 10, Val ID = 1
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Early stopping after 260 epochs
# Scores are: {'loss': 3.120096380371251e-06, 'AMS': 4.788291244406958}
# Fold took 114.520s
#
# Training model 3 / 10, Val ID = 2
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Early stopping after 260 epochs
# Scores are: {'loss': 3.1518541163677583e-06, 'AMS': 4.245978933609351}
# Fold took 115.773s
#
# Training model 4 / 10, Val ID = 3
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Early stopping after 320 epochs
# Scores are: {'loss': 3.2556604310229886e-06, 'AMS': 3.4904555265312713}
# Fold took 140.212s
#
# Training model 5 / 10, Val ID = 4
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Early stopping after 290 epochs
# Scores are: {'loss': 3.1829665658733575e-06, 'AMS': 3.7224027350487177}
# Fold took 129.030s
#
# Training model 6 / 10, Val ID = 5
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Early stopping after 335 epochs
# Scores are: {'loss': 3.1539609608444152e-06, 'AMS': 4.216031892433505}
# Fold took 147.110s
#
# Training model 7 / 10, Val ID = 6
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Early stopping after 295 epochs
# Scores are: {'loss': 3.2009577353164786e-06, 'AMS': 3.9821189466213225}
# Fold took 128.562s
#
# Training model 8 / 10, Val ID = 7
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Early stopping after 270 epochs
# Scores are: {'loss': 3.184539764333749e-06, 'AMS': 3.841170439518235}
# Fold took 116.977s
#
# Training model 9 / 10, Val ID = 8
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Early stopping after 280 epochs
# Scores are: {'loss': 3.1134070468397113e-06, 'AMS': 3.8646399247982988}
# Fold took 120.573s
#
# Training model 10 / 10, Val ID = 9
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Early stopping after 310 epochs
# Scores are: {'loss': 3.264469114583335e-06, 'AMS': 3.9829004375061254}
# Fold took 137.210s
#
#
# ______________________________________
# Training finished
# Cross-validation took 1278.867s
# Mean loss = 3.18e-06±2e-08
# Mean AMS = 4.0±0.1
# ______________________________________

# %% [markdown]
# ## Inference

# %% [markdown]
# ### Construct ensemble

# %%
with open('train_weights/results_file.pkl', 'rb') as fin:   
    results = pickle.load(fin)
with open('train_weights/cycle_file.pkl', 'rb') as fin:   
    cycle_losses = pickle.load(fin)

# %%
snapshot_args = {'cycle_losses': cycle_losses, 'patience':patience,
                 'n_cycles':8, 'load_cycles_only':0, 'weighting_pwr':0}
ensemble = Ensemble.from_results(results, ensemble_size, model_builder, snapshot_args=snapshot_args, metric='loss', higher_metric_better=False)
# Out:
# Choosing ensemble by loss
# /home/giles/cernbox/lumin/lumin/nn/ensemble/ensemble.py:221: UserWarning: Warning: Setting model weighting to uniform
#   warnings.warn("Warning: Setting model weighting to uniform")
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10/10 00:00<00:00]
#     </div>
# Model 0 is 8 with loss = 3.1134070468397113e-06
# Model 0 cycle 45 has loss = 3.1213523925543996e-06 and weight 1
# Model 0 cycle 44 has loss = 3.1337517611973453e-06 and weight 1
# Model 0 cycle 43 has loss = 3.130980985588394e-06 and weight 1
# Model 0 cycle 42 has loss = 3.1289703201764496e-06 and weight 1
# Model 0 cycle 41 has loss = 3.1262002266885247e-06 and weight 1
# Model 0 cycle 40 has loss = 3.134386133751832e-06 and weight 1
# Model 0 cycle 39 has loss = 3.132547135464847e-06 and weight 1
# Model 0 cycle 38 has loss = 3.1295232929551275e-06 and weight 1
# Model 1 is 1 with loss = 3.120096380371251e-06
# Model 1 cycle 41 has loss = 3.139931550322217e-06 and weight 1
# Model 1 cycle 40 has loss = 3.1335450785263674e-06 and weight 1
# Model 1 cycle 39 has loss = 3.1439408303413074e-06 and weight 1
# Model 1 cycle 38 has loss = 3.1493964343098924e-06 and weight 1
# Model 1 cycle 37 has loss = 3.129440528937266e-06 and weight 1
# Model 1 cycle 36 has loss = 3.128714524791576e-06 and weight 1
# Model 1 cycle 35 has loss = 3.1284362194128335e-06 and weight 1
# Model 1 cycle 34 has loss = 3.1291790492105065e-06 and weight 1
# Model 2 is 2 with loss = 3.1518541163677583e-06
# Model 2 cycle 41 has loss = 3.1625083920516772e-06 and weight 1
# Model 2 cycle 40 has loss = 3.1680324354965705e-06 and weight 1
# Model 2 cycle 39 has loss = 3.1814147405384574e-06 and weight 1
# Model 2 cycle 38 has loss = 3.179082568749436e-06 and weight 1
# Model 2 cycle 37 has loss = 3.1672789191361517e-06 and weight 1
# Model 2 cycle 36 has loss = 3.1730139653518563e-06 and weight 1
# Model 2 cycle 35 has loss = 3.1812337510928046e-06 and weight 1
# Model 2 cycle 34 has loss = 3.1742933970235754e-06 and weight 1
# Model 3 is 5 with loss = 3.1539609608444152e-06
# Model 3 cycle 56 has loss = 3.159537072860985e-06 and weight 1
# Model 3 cycle 55 has loss = 3.1622157621313818e-06 and weight 1
# Model 3 cycle 54 has loss = 3.1852991924097296e-06 and weight 1
# Model 3 cycle 53 has loss = 3.1764650429977337e-06 and weight 1
# Model 3 cycle 52 has loss = 3.181073907398968e-06 and weight 1
# Model 3 cycle 51 has loss = 3.1817621675145347e-06 and weight 1
# Model 3 cycle 50 has loss = 3.1720692277303897e-06 and weight 1
# Model 3 cycle 49 has loss = 3.164906047459226e-06 and weight 1
# Model 4 is 0 with loss = 3.1815486636332935e-06
# Model 4 cycle 45 has loss = 3.1921731533657294e-06 and weight 1
# Model 4 cycle 44 has loss = 3.1877057153906208e-06 and weight 1
# Model 4 cycle 43 has loss = 3.2056595955509692e-06 and weight 1
# Model 4 cycle 42 has loss = 3.188775508533581e-06 and weight 1
# Model 4 cycle 41 has loss = 3.2054406347015174e-06 and weight 1
# Model 4 cycle 40 has loss = 3.2047553304437315e-06 and weight 1
# Model 4 cycle 39 has loss = 3.202236712240847e-06 and weight 1
# Model 4 cycle 38 has loss = 3.191142923242296e-06 and weight 1
# Model 5 is 4 with loss = 3.1829665658733575e-06
# Model 5 cycle 47 has loss = 3.205043412890518e-06 and weight 1
# Model 5 cycle 46 has loss = 3.218974143237574e-06 and weight 1
# Model 5 cycle 45 has loss = 3.2021102924773004e-06 and weight 1
# Model 5 cycle 44 has loss = 3.208616362826433e-06 and weight 1
# Model 5 cycle 43 has loss = 3.198987087671412e-06 and weight 1
# Model 5 cycle 42 has loss = 3.2078071399155306e-06 and weight 1
# Model 5 cycle 41 has loss = 3.2074940463644452e-06 and weight 1
# Model 5 cycle 40 has loss = 3.1937747735355515e-06 and weight 1
# Model 6 is 7 with loss = 3.184539764333749e-06
# Model 6 cycle 43 has loss = 3.189665903846617e-06 and weight 1
# Model 6 cycle 42 has loss = 3.1869863050815184e-06 and weight 1
# Model 6 cycle 41 has loss = 3.1956642487784848e-06 and weight 1
# Model 6 cycle 40 has loss = 3.188914433849277e-06 and weight 1
# Model 6 cycle 39 has loss = 3.1966076221578987e-06 and weight 1
# Model 6 cycle 38 has loss = 3.201606432412518e-06 and weight 1
# Model 6 cycle 37 has loss = 3.207720055797836e-06 and weight 1
# Model 6 cycle 36 has loss = 3.187277570759761e-06 and weight 1
# Model 7 is 6 with loss = 3.2009577353164786e-06
# Model 7 cycle 48 has loss = 3.2233158435701625e-06 and weight 1
# Model 7 cycle 47 has loss = 3.217940047761658e-06 and weight 1
# Model 7 cycle 46 has loss = 3.218333404220175e-06 and weight 1
# Model 7 cycle 45 has loss = 3.2182801987801213e-06 and weight 1
# Model 7 cycle 44 has loss = 3.2204338822339196e-06 and weight 1
# Model 7 cycle 43 has loss = 3.2202676720771706e-06 and weight 1
# Model 7 cycle 42 has loss = 3.212481715308968e-06 and weight 1
# Model 7 cycle 41 has loss = 3.2197613109019585e-06 and weight 1
# Model 8 is 3 with loss = 3.2556604310229886e-06
# Model 8 cycle 53 has loss = 3.2618290788377635e-06 and weight 1
# Model 8 cycle 52 has loss = 3.277071755292127e-06 and weight 1
# Model 8 cycle 51 has loss = 3.2766329240985215e-06 and weight 1
# Model 8 cycle 50 has loss = 3.258797050875728e-06 and weight 1
# Model 8 cycle 49 has loss = 3.266228304710239e-06 and weight 1
# Model 8 cycle 48 has loss = 3.263539156250772e-06 and weight 1
# Model 8 cycle 47 has loss = 3.273080665167072e-06 and weight 1
# Model 8 cycle 46 has loss = 3.270336264904472e-06 and weight 1
# Model 9 is 9 with loss = 3.264469114583335e-06
# Model 9 cycle 51 has loss = 3.285470484115649e-06 and weight 1
# Model 9 cycle 50 has loss = 3.282572606622125e-06 and weight 1
# Model 9 cycle 49 has loss = 3.280108785475022e-06 and weight 1
# Model 9 cycle 48 has loss = 3.295749365861411e-06 and weight 1
# Model 9 cycle 47 has loss = 3.27794282384275e-06 and weight 1
# Model 9 cycle 46 has loss = 3.2850048228283413e-06 and weight 1
# Model 9 cycle 45 has loss = 3.2739926609792747e-06 and weight 1
# Model 9 cycle 44 has loss = 3.2975424346659565e-06 and weight 1

# %% [markdown]
# ### Validation

# %% [markdown]
# #### Response on validation data without TTA

# %%
val_fy = FoldYielder(DATA_PATH/'val.hdf5')

# %%
val_timer = timeit.default_timer()
ensemble.predict(val_fy)
val_time = timeit.default_timer()-val_timer
experiment['val_time_no_tta'] = val_time
# Out:
# Mean time per event = 1.32e-05±2e-07

# %%
val_df = val_fy.get_df()
# Out:
# 50000 datapoints loaded

# %%
cut, experiment['val_ams_smooth_no_tta'], experiment['val_ams_max_no_tta'] = binary_class_cut_by_ams(val_df, top_perc=10, br=10, wgt_factor=250000/50000)
# Out:
# Mean cut at 0.9421173930168152 corresponds to AMS of 3.719972998023527
# Maximum AMS for data is 3.7450468733822575 at cut of 0.9451665878295898

# %% [markdown]
# #### Response on validation data with TTA

# %%
val_fy = HEPAugFoldYielder(DATA_PATH/'val.hdf5', rot_mult=2)
# Out:
# Augmenting via phi rotations
# Augmenting via y flips
# Augmenting via longitunidnal flips
# Total augmentation multiplicity is 8

# %%
val_timer = timeit.default_timer()
ensemble.predict(val_fy, pred_name='pred_tta')
val_time = timeit.default_timer()-val_timer
experiment['val_time'] = val_time
# Out:
# Mean time per event = 0.000199±1e-06

# %%
val_df = val_fy.get_df(pred_name='pred_tta')
# Out:
# 50000 datapoints loaded

# %%
cut_tta, experiment['val_ams_smooth'], experiment['val_ams_max'] = binary_class_cut_by_ams(val_df, top_perc=10, br=10, wgt_factor=250000/50000)
# Out:
# Mean cut at 0.9417943358421326 corresponds to AMS of 3.721203144624791
# Maximum AMS for data is 3.75915430904811 at cut of 0.9447097182273865

# %% [markdown]
# ### Testing

# %% [markdown]
# #### Test scoring without TTA

# %%
test_fy = FoldYielder(DATA_PATH/'test.hdf5')

# %%
test_timer = timeit.default_timer()
ensemble.predict(test_fy)
test_time = timeit.default_timer()-test_timer
experiment['test_time_no_tta'] = test_time
# Out:
# Mean time per event = 6.39e-06±5e-08

# %%
experiment['test_public_ams_mean_no_tta'], experiment['test_private_ams_mean_no_tta'] = score_test_data_per_fold(test_fy, cut, pred_name='pred')
# Out:
# Mean Public:Private AMS: 3.77±0.06 : 3.76±0.04

# %%
experiment['test_public_ams_no_tta'], experiment['test_private_ams_no_tta'] = score_test_data(test_fy, cut, pred_name='pred')
# Out:
# Public:Private AMS: 3.753755683483895 : 3.7591059321281133

# %% [markdown]
# #### Test scoring with TTA

# %%
test_fy = HEPAugFoldYielder(DATA_PATH/'test.hdf5', rot_mult=2)
# Out:
# Augmenting via phi rotations
# Augmenting via y flips
# Augmenting via longitunidnal flips
# Total augmentation multiplicity is 8

# %%
test_timer = timeit.default_timer()
ensemble.predict(test_fy, pred_name='pred_tta')
test_time = timeit.default_timer()-test_timer
experiment['test_time'] = test_time
# Out:
# Mean time per event = 0.000115±1e-06

# %%
experiment['test_public_ams_mean'], experiment['test_private_ams_mean'] = score_test_data_per_fold(test_fy, cut_tta, pred_name='pred_tta')
# Out:
# Mean Public:Private AMS: 3.75±0.07 : 3.76±0.03

# %%
experiment['test_public_ams'], experiment['test_private_ams'] = score_test_data(test_fy, cut_tta, pred_name='pred_tta')
# Out:
# Public:Private AMS: 3.738786470279079 : 3.761232929973479

# %% [markdown]
# ## Results

# %%
experiment
# Out:
# Experiment:	8_swish_ensemble_embed_aug_fge
# Machine:	helios_cuda
# Device:	Nvidia GeForce GTX 1080 Ti GPU
# train_time	1279.3318059599987
# val_time_no_tta	0.6676352569993469
# val_ams_smooth_no_tta	3.719972998023527
# val_ams_max_no_tta	3.7450468733822575
# val_time	9.973275588999968
# val_ams_smooth	3.721203144624791
# val_ams_max	3.75915430904811
# test_time_no_tta	3.5274930899995525
# test_public_ams_mean_no_tta	(3.765413283420834, 0.06492974711987046)
# test_private_ams_mean_no_tta	(3.762570146153814, 0.03772481860943038)
# test_public_ams_no_tta	3.753755683483895
# test_private_ams_no_tta	3.7591059321281133
# test_time	63.050680890000876
# test_public_ams_mean	(3.751465112663438, 0.06685344083691934)
# test_private_ams_mean	(3.764230845085115, 0.03428165171064569)
# test_public_ams	3.738786470279079
# test_private_ams	3.761232929973479

# %%
experiment.save()

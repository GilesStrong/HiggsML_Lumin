# %% [markdown]
# # Swish-based ensemble with categorical entity embedding
# - SWish activation, 4 layers, 100 neurons per layer
# - PRI_jet_num embedded
# - Train-time/test-time data augmentation
# - SWA + cosine
# - Validation score use ensemble of 10 models weighted by loss

# %% [markdown]
# ### Import modules

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
from __future__ import division
import sys
import os
sys.path.append('../../')
from modules.basics import *

# %%
NAME = '10_swish_ensemble_embed_aug_swacosine1'

# %%
experiment = Experiment(NAME, 'mbp', RESULTS_PATH)

# %%
# !python ../../modules/data_import.py -d ../../data/ -f PRI_jet_num -s {experiment.seed}
# Out:
# Converting to use_cartesian coordinates
# Converting to use_cartesian coordinates
# Training on 200000 datapoints and validating on 50000, using 31 feats:
# ['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet', 'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt', 'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality', 'DER_lep_eta_centrality', 'PRI_met_sumet', 'PRI_jet_num', 'PRI_jet_all_pt', 'PRI_met_px', 'PRI_met_py', 'PRI_jet_subleading_px', 'PRI_jet_subleading_py', 'PRI_jet_subleading_pz', 'PRI_jet_leading_px', 'PRI_jet_leading_py', 'PRI_jet_leading_pz', 'PRI_lep_px', 'PRI_lep_py', 'PRI_lep_pz', 'PRI_tau_px', 'PRI_tau_py', 'PRI_tau_pz', 'PRI_met_pt']
# Saving fold 0 with 20003 events
# Saving fold 1 with 20003 events
# Saving fold 2 with 20003 events
# Saving fold 3 with 20003 events
# Saving fold 4 with 20002 events
# Saving fold 5 with 20001 events
# Saving fold 6 with 19999 events
# Saving fold 7 with 19996 events
# Saving fold 8 with 19995 events
# Saving fold 9 with 19995 events
# Saving fold 0 with 5003 events
# Saving fold 1 with 5003 events
# Saving fold 2 with 5002 events
# Saving fold 3 with 5002 events
# Saving fold 4 with 5001 events
# Saving fold 5 with 5001 events
# Saving fold 6 with 5000 events
# Saving fold 7 with 4997 events
# Saving fold 8 with 4996 events
# Saving fold 9 with 4995 events
# gen_strat_key not found in DataFrame
# Saving fold 0 with 55000 events
# Saving fold 1 with 55000 events
# Saving fold 2 with 55000 events
# Saving fold 3 with 55000 events
# Saving fold 4 with 55000 events
# Saving fold 5 with 55000 events
# Saving fold 6 with 55000 events
# Saving fold 7 with 55000 events
# Saving fold 8 with 55000 events
# Saving fold 9 with 55000 events

# %% [markdown]
# ## Training

# %% [markdown]
# ### Import data

# %%
train_fy = HEPAugFoldYielder(DATA_PATH/'train.hdf5', rot_mult=2)
# Out:
# Augmenting via phi rotations
# Augmenting via y flips
# Augmenting via longitunidnal flips
# Total augmentation multiplicity is 8

# %%
train_feats = train_fy.cont_feats+train_fy.cat_feats

# %%
id=3
aug_ranges = [range(4), range(4,8)]
for aug_range in aug_ranges:
    compare_events([pd.DataFrame(train_fy.get_test_fold(0, i)['inputs'], columns=train_feats)[id:id+1] for i in aug_range])
# Out:
# /Users/giles/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# /Users/giles/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
id=3
compare_events([pd.DataFrame(train_fy.get_fold(0)['inputs'], columns=train_feats)[id:id+1] for i in range(4)])
# Out:
# /Users/giles/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %% [markdown]
# ### Options

# %%
n_models = 10
patience = 10
max_epochs = 200
ensemble_size = 10

bs = 256
objective = 'classification'
model_args = {'body':{'act':'swish', 'width':100, 'depth':4}}
opt_args = {'opt':'adam', 'eps':1e-08}
cat_embedder = CatEmbedder.from_fy(train_fy, emb_szs=[3])

n_out = 1
model_builder = ModelBuilder(objective, cont_feats=train_fy.cont_feats, n_out=n_out, cat_embedder=cat_embedder,
                             model_args=model_args, opt_args=opt_args)
Model(model_builder)
# Out:
# Inputs:
# 30 Continuous: ['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet', 'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt', 'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality', 'DER_lep_eta_centrality', 'PRI_met_sumet', 'PRI_jet_all_pt', 'PRI_met_px', 'PRI_met_py', 'PRI_jet_subleading_px', 'PRI_jet_subleading_py', 'PRI_jet_subleading_pz', 'PRI_jet_leading_px', 'PRI_jet_leading_py', 'PRI_jet_leading_pz', 'PRI_lep_px', 'PRI_lep_py', 'PRI_lep_pz', 'PRI_tau_px', 'PRI_tau_py', 'PRI_tau_pz', 'PRI_met_pt']
#
# 1  Categorical: ['PRI_jet_num']
#
# 0  Matrix elements: []
#
#
# Model:
# <bound method Module.parameters of Sequential(
#   (0): CatEmbHead(
#     (embeds): ModuleList(
#       (0): Embedding(4, 3)
#     )
#   )
#   (1): FullyConnected(
#     (layers): Sequential(
#       (0): Sequential(
#         (0): Linear(in_features=33, out_features=100, bias=True)
#         (1): Swish()
#       )
#       (1): Sequential(
#         (0): Linear(in_features=100, out_features=100, bias=True)
#         (1): Swish()
#       )
#       (2): Sequential(
#         (0): Linear(in_features=100, out_features=100, bias=True)
#         (1): Swish()
#       )
#       (3): Sequential(
#         (0): Linear(in_features=100, out_features=100, bias=True)
#         (1): Swish()
#       )
#     )
#   )
#   (2): ClassRegMulti(
#     (dense): Linear(in_features=100, out_features=1, bias=True)
#     (act): Sigmoid()
#   )
# )>
#
#
# Number of trainable parameters: 33813
#
#
# Optimiser:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
#
#
# Loss:
# <class 'torch.nn.modules.loss.BCELoss'>

# %% [markdown]
# ### Determine LR

# %%
lr_finder = fold_lr_find(train_fy, model_builder, 256, lr_bounds=[1e-5,1e1])
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10/10 00:05<00:00]
#     </div>
# LR finder took 5.454s

# %% [markdown]
# ### Train classifier

# %%
callback_partials = [partial(CycleLR, lr_range=(2e-4, 2e-3), cycle_mult=1 ,scale=5),
                     partial(SWA, start_epoch=2, renewal_period=2, verbose=False)]
eval_metrics = {'AMS':AMS(n_total=250000, br=10, wgt_name='gen_weight_original')}

# %%
train_timer = timeit.default_timer()
results, histories, cycle_losses = fold_train_ensemble(train_fy, n_models,
                                                       model_builder=model_builder,
                                                       bs=bs,
                                                       callback_partials=callback_partials,
                                                       eval_metrics=eval_metrics,
                                                       max_epochs=max_epochs, patience=patience)
train_time = timeit.default_timer()-train_timer
experiment['train_time'] = train_time
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/10 00:00<00:00]
#     </div>
# Training model 1 / 10, Val ID = 0
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-6d9d1203213c> in <module>()
#       5                                                        callback_partials=callback_partials,
#       6                                                        eval_metrics=eval_metrics,
# ----> 7                                                        max_epochs=max_epochs, patience=patience)
#       8 train_time = timeit.default_timer()-train_timer
#       9 experiment['train_time'] = train_time
#
# ~/cernbox/lumin/lumin/nn/training/fold_train.py in fold_train_ensemble(fy, n_models, bs, model_builder, callback_partials, eval_metrics, train_on_weights, eval_on_weights, patience, max_epochs, plots, shuffle_fold, shuffle_folds, bulk_move, savepath, verbose, log_output, plot_settings)
#     160                 loss_history['trn_loss'].append(model.fit(batch_yielder, callbacks))
#     161
# --> 162                 val_loss = model.evaluate(val_x, val_y, weights=val_w, callbacks=callbacks)
#     163                 loss_history['val_loss'].append(val_loss)
#     164                 loss_callback_idx = None
#
# ~/cernbox/lumin/lumin/nn/models/model.py in evaluate(self, inputs, targets, weights, callbacks, mask_inputs)
#     181             else:
#     182                 inputs = inputs[:,self.input_mask]
# --> 183         y_pred = self.model(inputs)
#     184
#     185         if not isinstance(targets, Tensor): targets = to_device(Tensor(targets))
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/cernbox/lumin/lumin/nn/models/blocks/head.py in forward(self, x)
#     186             x_cont = x[:,:self.n_cont_in]
#     187             if self.do_cont > 0: x_cont = self.cont_in_do(x_cont)
# --> 188             x_out = torch.cat((x_cont, x_out), dim=1) if self.cat_embedder.n_cat_in > 0 else x_cont
#     189         return x_out
#     190
#
# KeyboardInterrupt:

# %% [markdown]
# ## Inference

# %% [markdown]
# ### Construct ensemble

# %%
with open('train_weights/results_file.pkl', 'rb') as fin:   
    results = pickle.load(fin)
with open('train_weights/cycle_file.pkl', 'rb') as fin:   
    cycle_losses = pickle.load(fin)

# %%
ensemble = Ensemble.from_results(results, ensemble_size, model_builder, metric='loss', higher_metric_better=False)

# %% [markdown]
# ### Validation

# %% [markdown]
# #### Response on validation data without TTA

# %%
val_fy = FoldYielder(DATA_PATH/'val.hdf5')

# %%
val_timer = timeit.default_timer()
ensemble.predict(val_fy)
val_time = timeit.default_timer()-val_timer
experiment['val_time_no_tta'] = val_time
# Out:
# Total time: 00:00 <p>
# Mean time per event = 1.52e-05±4e-07

# %%
val_df = val_fy.get_df()
# Out:
# 50000 candidates loaded

# %%
cut, experiment['val_ams_smooth_no_tta'], experiment['val_ams_max_no_tta'] = binary_class_cut_by_ams(val_df, top_perc=10, br=10, wgt_factor=250000/50000)
# Out:
# Mean cut at 0.9361011981964111 corresponds to AMS of 3.8163705991308694
# Maximum AMS for data is 3.8771860223662085 at cut of 0.938599169254303
# /Users/giles/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %% [markdown]
# #### Response on validation data with TTA

# %%
val_fy = HEPAugFoldYielder(DATA_PATH/'val.hdf5'rot_mult=2)
# Out:
# Augmenting via phi rotations
# Augmenting via y flips
# Augmenting via longitunidnal flips
# Total augmentation multiplicity is 8

# %%
val_timer = timeit.default_timer()
ensemble.predict(val_fy, pred_name='pred_tta')
val_time = timeit.default_timer()-val_timer
experiment['val_time'] = val_time
# Out:
# Total time: 00:09 <p>
# Mean time per event = 0.000191±1e-06

# %%
val_df = val_fy.get_df(pred_name='pred_tta')
# Out:
# 50000 candidates loaded

# %%
cut_tta, experiment['val_ams_smooth'], experiment['val_ams_max'] = binary_class_cut_by_ams(val_df, top_perc=10, br=10, wgt_factor=250000/50000)
# Out:
# Mean cut at 0.9356101751327515 corresponds to AMS of 3.8330172160139804
# Maximum AMS for data is 3.873232555177483 at cut of 0.9378893971443176
# /Users/giles/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %% [markdown]
# ### Testing

# %% [markdown]
# #### Test scoring without TTA

# %%
test_fy = FoldYielder(DATA_PATH/'testing.hdf5')

# %%
test_timer = timeit.default_timer()
ensemble.predict(test_fy)
test_time = timeit.default_timer()-test_timer
experiment['test_time_no_tta'] = test_time
# Out:
# Total time: 00:08 <p>
# Mean time per event = 1.59e-05±3e-07

# %%
experiment['test_public_ams_mean_no_tta'], experiment['test_private_ams_mean_no_tta'] = score_test_data_per_fold(test_fy, cut, pred_name='pred')
# Out:
# Mean Public:Private AMS: 3.78±0.06 : 3.73±0.04

# %%
experiment['test_public_ams_no_tta'], experiment['test_private_ams_no_tta'] = score_test_data(test_fy, cut, pred_name='pred')
# Out:
# Public:Private AMS: 3.768647292718845 : 3.722010453523056

# %% [markdown]
# #### Test scoring with TTA

# %%
test_fy = HEPAugFoldYielder(DATA_PATH/'testing.hdf5'rot_mult=2)
# Out:
# Augmenting via phi rotations
# Augmenting via y flips
# Augmenting via longitunidnal flips
# Total augmentation multiplicity is 8

# %%
test_timer = timeit.default_timer()
ensemble.predict(test_fy, pred_name='pred_tta')
test_time = timeit.default_timer()-test_timer
experiment['test_time'] = test_time
# Out:
# Total time: 01:36 <p>
# Mean time per event = 0.000176±6e-06

# %%
experiment['test_public_ams_mean'], experiment['test_private_ams_mean'] = score_test_data_per_fold(test_fy, cut_tta, pred_name='pred_tta')
# Out:
# Mean Public:Private AMS: 3.78±0.08 : 3.75±0.04

# %%
experiment['test_public_ams'], experiment['test_private_ams'] = score_test_data(test_fy, cut_tta, pred_name='pred_tta')
# Out:
# Public:Private AMS: 3.7593005196572586 : 3.741541022949231

# %% [markdown]
# ## Results

# %%
experiment
# Out:
# Experiment:	7_relu_ensemble_embed_aug
# Machine:	mbp
# Device:	Intel Core i7-8559U CPU @ 2.7 GHz x 4
# train_time	1420.586964852002
# val_time_no_tta	0.7701200960000278
# val_ams_smooth_no_tta	3.8163705991308694
# val_ams_max_no_tta	3.8771860223662085
# val_time	9.568701434000104
# val_ams_smooth	3.8330172160139804
# val_ams_max	3.873232555177483
# test_time_no_tta	8.769647453998914
# test_public_ams_mean_no_tta	(3.776825824403776, 0.06065043296022456)
# test_private_ams_mean_no_tta	(3.727019692815601, 0.04197842588305641)
# test_public_ams_no_tta	3.768647292718845
# test_private_ams_no_tta	3.722010453523056
# test_time	96.96949299300104
# test_public_ams_mean	(3.7783938631592227, 0.08359880013792029)
# test_private_ams_mean	(3.7465407033720437, 0.040738579954956125)
# test_public_ams	3.7593005196572586
# test_private_ams	3.741541022949231

# %%
experiment.save()
